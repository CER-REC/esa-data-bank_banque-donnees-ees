# %%
import pandas as pd
import os
import glob
import shutil
from time import gmtime, strftime

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)

# %%
# filepath to the English and French index files
ENG_index_filepath = 'F:/Environmental Baseline Data/Version 4 - Final/Indices/ESA_website_ENG.csv'
FRA_index_filepath = 'F:/Environmental Baseline Data/Version 4 - Final/Indices/ESA_website_FRA.csv'

# %%
# Loading index file of all tables
df = pd.read_csv(ENG_index_filepath)
df_FRA = pd.read_csv(FRA_index_filepath)

# %%
# Remove all rows for figures so that we are only moving tables
df = df[df['Content Type'] == 'Table']
df_FRA = df_FRA[df_FRA['Type de contenu'] == 'Tableau']

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df = df.reset_index()
df.rename(columns = {"index": "Index"}, inplace = True) 

df_FRA.drop(columns=['Unnamed: 0'], inplace=True)
df_FRA = df_FRA.reset_index()
df_FRA.rename(columns = {"Index": "Indice"}, inplace = True)

# %%
df['filename'] = df['Download folder name'] + '-' + df['Title'].str.lower().str.replace('(', '').str.replace(')', '').str.replace(' ', '-').str.replace('.', '-').str.replace('[^\w+-]', '').str.slice(0,80)

df_FRA['nom_du_fichier'] = df_FRA['Télécharger le nom du dossier'] + '-' + df_FRA['Titre'].str.lower().str.replace('(', '').str.replace(')', '').str.replace(' ', '-').str.replace('.', '-').str.replace('[^\w+-]', '').str.slice(0,80)

# %%
old_filename_df = df['CSV Download URL'].str.split('/').str[-1].str.split('_')
df['old_filename'] = old_filename_df.str[0] + '_' + old_filename_df.str[1] + '_lattice-v_' + old_filename_df.str[2]

vieux_nom_du_fichier_df = df_FRA['URL de téléchargement CSV'].str.split('/').str[-1].str.split('_')
df_FRA['vieux_nom_de_fichier'] = vieux_nom_du_fichier_df.str[0] + '_' + vieux_nom_du_fichier_df.str[1] + '_lattice-v_' + vieux_nom_du_fichier_df.str[2]

# %%
# %%time
prev_title = ''
for index, row in df.iterrows():
    current_title = row['filename']
    if current_title == prev_title:
        i += 1
        current_title = current_title + '-pg' + str(row['PDF Page Number']) + '-pt' + str(i)
#         print(i)
    else:
        i = 1
        current_title = current_title + '-pg' + str(row['PDF Page Number']) + '-pt' + str(i)
    
    df.loc[index, 'filename'] = current_title
    df.loc[index, 'CSV Download URL'] = os.path.join('http://www.cer-rec.gc.ca/esa-ees/', row['Download folder name'] + '/' + current_title + '.csv')
    prev_title = row['filename']
# Out:
# Wall time: 2min 9s

# %%
df.head(5)
# Out:
#    Index  \
# 0   9134
# 1   9135
# 2   9136
# 3   9137
# 4   9138
#
#                                                                                               Title  \
# 0   TABLE 3 SUMMARY OF AQUATICS FIELD WORK AND ABORIGINAL FIELD STUDY PARTICIPATION FOR THE PROJECT
# 1  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 2  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 3  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 4  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
#
#   Content Type                       Application Name Application Short Name  \
# 0        Table  Application for North Montney Project          North Montney
# 1        Table  Application for North Montney Project          North Montney
# 2        Table  Application for North Montney Project          North Montney
# 3        Table  Application for North Montney Project          North Montney
# 4        Table  Application for North Montney Project          North Montney
#
#   Application Filing Date                Company Name Commodity  \
# 0              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 1              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 2              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 3              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 4              2013-11-08  NOVA Gas Transmission Ltd.       Gas
#
#                                 File Name  \
# 0  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 1  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 2  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 3  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 4  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
#
#                                                ESA Folder URL Document Number  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
#
#    Data ID                                          PDF Download URL  \
# 0  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 1  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 2  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 3  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 4  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
#
#     Application Type (NEB Act) Pipeline Location Hearing order  \
# 0  Large Projects (over 40 km)  British Columbia   GH-001-2014
# 1  Large Projects (over 40 km)  British Columbia   GH-001-2014
# 2  Large Projects (over 40 km)  British Columbia   GH-001-2014
# 3  Large Projects (over 40 km)  British Columbia   GH-001-2014
# 4  Large Projects (over 40 km)  British Columbia   GH-001-2014
#
#                                            Consultant Name Pipeline Status  \
# 0  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 1  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 2  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 3  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 4  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
#
#   Regulatory Instrument(s)  \
# 0                   GC-125
# 1                   GC-125
# 2                   GC-125
# 3                   GC-125
# 4                   GC-125
#
#                                         Application URL  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
#
#                                            Decision URL  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
#
#                              ESA Section(s)  ESA Section(s) Index  \
# 0  Appendix G: TERA Aquatics Summary Report                  15.0
# 1  Appendix G: TERA Aquatics Summary Report                  15.0
# 2  Appendix G: TERA Aquatics Summary Report                  15.0
# 3  Appendix G: TERA Aquatics Summary Report                  15.0
# 4  Appendix G: TERA Aquatics Summary Report                  15.0
#
#   ESA Section(s) Topics  \
# 0                 Water
# 1                 Water
# 2                 Water
# 3                 Water
# 4                 Water
#
#                                                                                                                                    CSV Download URL  \
# 0  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn-table-3-summary-of-aquatics-field-work-and-aboriginal-field-study-participation--pg14-pt1.csv
# 1  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn-table-4-summary-of-watercourse-crossings-along-the-north-montney-mainline-aitken-pg17-pt1.csv
# 2  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn-table-4-summary-of-watercourse-crossings-along-the-north-montney-mainline-aitken-pg18-pt2.csv
# 3  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn-table-4-summary-of-watercourse-crossings-along-the-north-montney-mainline-aitken-pg19-pt3.csv
# 4  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn-table-4-summary-of-watercourse-crossings-along-the-north-montney-mainline-aitken-pg20-pt4.csv
#
#    PDF Page Number  PDF Page Count  PDF Size PDF Outline Download folder name  \
# 0               14            48.0      5.87          No             nrthmntn
# 1               17            48.0      5.87          No             nrthmntn
# 2               18            48.0      5.87          No             nrthmntn
# 3               19            48.0      5.87          No             nrthmntn
# 4               20            48.0      5.87          No             nrthmntn
#
#                              Zipped Project Link  \
# 0  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
# 1  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
# 2  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
# 3  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
# 4  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
#
#                                                                                              filename  \
# 0  nrthmntn-table-3-summary-of-aquatics-field-work-and-aboriginal-field-study-participation--pg14-pt1
# 1  nrthmntn-table-4-summary-of-watercourse-crossings-along-the-north-montney-mainline-aitken-pg17-pt1
# 2  nrthmntn-table-4-summary-of-watercourse-crossings-along-the-north-montney-mainline-aitken-pg18-pt2
# 3  nrthmntn-table-4-summary-of-watercourse-crossings-along-the-north-montney-mainline-aitken-pg19-pt3
# 4  nrthmntn-table-4-summary-of-watercourse-crossings-along-the-north-montney-mainline-aitken-pg20-pt4
#
#                  old_filename
# 0  1059614_14_lattice-v_1.csv
# 1  1059614_17_lattice-v_1.csv
# 2  1059614_18_lattice-v_1.csv
# 3  1059614_19_lattice-v_1.csv
# 4  1059614_20_lattice-v_1.csv

# %%
# %%time
# For French index file
i = 1
prev_title = ''
for index, row in df_FRA.iterrows():
    current_title = row['nom_du_fichier']
    if current_title == prev_title:
        i += 1
        current_title = current_title + '-pg' + str(row['Numéro de page PDF']) + '-pt' + str(i)
#         print(i)
    else:
        i = 1
        current_title = current_title + '-pg' + str(row['Numéro de page PDF']) + '-pt' + str(i)
    
    df_FRA.loc[index, 'nom_du_fichier'] = current_title
    df_FRA.loc[index, 'URL de téléchargement CSV'] = os.path.join('http://www.cer-rec.gc.ca/esa-ees/', row['Télécharger le nom du dossier'] + '/' + current_title + '.csv')
    prev_title = row['nom_du_fichier']
# Out:
# Wall time: 2min 1s

# %%
df_FRA.head(5)
# Out:
#    index  \
# 0   9134
# 1   9135
# 2   9136
# 3   9137
# 4   9138
#
#                                                                                               Titre  \
# 0   TABLE 3 SUMMARY OF AQUATICS FIELD WORK AND ABORIGINAL FIELD STUDY PARTICIPATION FOR THE PROJECT
# 1  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 2  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 3  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 4  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
#
#   Type de contenu                       Nom de la demande  \
# 0         Tableau  Demande visant le projet North Montney
# 1         Tableau  Demande visant le projet North Montney
# 2         Tableau  Demande visant le projet North Montney
# 3         Tableau  Demande visant le projet North Montney
# 4         Tableau  Demande visant le projet North Montney
#
#   Nom abrégé de la demande Dépôt de la demande           Nom de la société  \
# 0            North Montney          2013-11-08  NOVA Gas Transmission Ltd.
# 1            North Montney          2013-11-08  NOVA Gas Transmission Ltd.
# 2            North Montney          2013-11-08  NOVA Gas Transmission Ltd.
# 3            North Montney          2013-11-08  NOVA Gas Transmission Ltd.
# 4            North Montney          2013-11-08  NOVA Gas Transmission Ltd.
#
#   Produit de base                          Nom de fichier  \
# 0             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 1             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 2             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 3             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 4             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
#
#                                       URL du dossier de l’ÉES  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
#
#   Numéro de document  Identificateur de données  \
# 0             A3Q6H2                    1059614
# 1             A3Q6H2                    1059614
# 2             A3Q6H2                    1059614
# 3             A3Q6H2                    1059614
# 4             A3Q6H2                    1059614
#
#                                   URL de téléchargement PDF  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 1  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 2  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 3  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 4  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
#
#   Type de demande (Loi sur l’Office national de l’énergie)  \
# 0              Projets de grande envergure (plus de 40 km)
# 1              Projets de grande envergure (plus de 40 km)
# 2              Projets de grande envergure (plus de 40 km)
# 3              Projets de grande envergure (plus de 40 km)
# 4              Projets de grande envergure (plus de 40 km)
#
#   Emplacement du pipeline Ordonnance d’audience  \
# 0    Colombie britannique           GH-001-2014
# 1    Colombie britannique           GH-001-2014
# 2    Colombie britannique           GH-001-2014
# 3    Colombie britannique           GH-001-2014
# 4    Colombie britannique           GH-001-2014
#
#                                          Nom du consultant État d'avancement  \
# 0  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
# 1  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
# 2  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
# 3  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
# 4  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
#
#   Instruments réglementaires  \
# 0                     GC-125
# 1                     GC-125
# 2                     GC-125
# 3                     GC-125
# 4                     GC-125
#
#                                       URL de la demande  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
#
#                                                       URL de la décision  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
# 1  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
# 2  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
# 3  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
# 4  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
#
#                           Sections de l’EES  Index des sections de l’ÉES  \
# 0  Appendix G: TERA Aquatics Summary Report                         15.0
# 1  Appendix G: TERA Aquatics Summary Report                         15.0
# 2  Appendix G: TERA Aquatics Summary Report                         15.0
# 3  Appendix G: TERA Aquatics Summary Report                         15.0
# 4  Appendix G: TERA Aquatics Summary Report                         15.0
#
#   Sujets des sections de l’ÉES  \
# 0                          Eau
# 1                          Eau
# 2                          Eau
# 3                          Eau
# 4                          Eau
#
#                                                                         URL de téléchargement CSV  \
# 0  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn-table-3-summary-of-aquatics-fi-pg14-pt1.csv
# 1  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn-table-4-summary-of-watercourse-pg17-pt1.csv
# 2  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn-table-4-summary-of-watercourse-pg18-pt2.csv
# 3  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn-table-4-summary-of-watercourse-pg19-pt3.csv
# 4  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn-table-4-summary-of-watercourse-pg20-pt4.csv
#
#    Numéro de page PDF  Nombre de pages PDF  Taille PDF Aperçu PDF  \
# 0                  14                 48.0        5.87        Non
# 1                  17                 48.0        5.87        Non
# 2                  18                 48.0        5.87        Non
# 3                  19                 48.0        5.87        Non
# 4                  20                 48.0        5.87        Non
#
#   Télécharger le nom du dossier  \
# 0                      nrthmntn
# 1                      nrthmntn
# 2                      nrthmntn
# 3                      nrthmntn
# 4                      nrthmntn
#
#                    Lien vers le projet compressé  \
# 0  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
# 1  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
# 2  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
# 3  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
# 4  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
#
#                                      nom_du_fichier  \
# 0  nrthmntn-table-3-summary-of-aquatics-fi-pg14-pt1
# 1  nrthmntn-table-4-summary-of-watercourse-pg17-pt1
# 2  nrthmntn-table-4-summary-of-watercourse-pg18-pt2
# 3  nrthmntn-table-4-summary-of-watercourse-pg19-pt3
# 4  nrthmntn-table-4-summary-of-watercourse-pg20-pt4
#
#          vieux_nom_de_fichier
# 0  1059614_14_lattice-v_1.csv
# 1  1059614_17_lattice-v_1.csv
# 2  1059614_18_lattice-v_1.csv
# 3  1059614_19_lattice-v_1.csv
# 4  1059614_20_lattice-v_1.csv

# %%
len(df)
# Out:
# 28891

# %%
len(df['filename'].unique())
# Out:
# 28664

# %%
df['filename'][df['filename'].duplicated() == True]
# Out:
# 1042            tmx-table-8-4-2-significance-evaluation-of-the-projects-contribution-to-cumulative-e-pg49-pt1
# 1043            tmx-table-8-4-2-significance-evaluation-of-the-projects-contribution-to-cumulative-e-pg50-pt2
# 1794            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg12-pt1
# 1795            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg13-pt2
# 1796            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg14-pt3
# 1797            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg15-pt4
# 1810            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg12-pt1
# 1811            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg13-pt2
# 1812            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg14-pt3
# 1813            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg15-pt4
# 2107            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg12-pt1
# 2108            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg13-pt2
# 2109            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg14-pt3
# 2110            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg15-pt4
# 2451            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg12-pt1
# 2452            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg13-pt2
# 2453            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg14-pt3
# 2454            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg15-pt4
# 2703            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg12-pt1
# 2704            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg13-pt2
# 2705            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg14-pt3
# 2706            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg15-pt4
# 2826            tmx-table-4-2-3-evaluation-of-alternative-corridors--north-thompson-river-provincial-pg11-pt1
# 2827            tmx-table-4-2-4-evaluation-of-alternative-corridors--lac-du-bois-grasslands-protecte-pg16-pt1
# 2828            tmx-table-4-2-5-evaluation-of-alternative-corridors---coldwater-indian-reserve-kp-90-pg18-pt1
# 2829            tmx-table-4-2-6-evaluation-of-alternative-corridors--coldwater-river-provincial-park-pg20-pt1
# 2830             tmx-table-4-2-1-evaluation-of-alternative-corridors--five-north-thompson-river-cross-pg7-pt1
# 2831             tmx-table-4-2-2-evaluation-of-alternative-corridors--finn-creek-provincial-park-kp-6-pg9-pt1
# 3230            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg12-pt1
# 3231            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg13-pt2
# 3232            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg14-pt3
# 3233            tmx-table-a-1-circumstances-and-interactions-requiring-detailed-biophysical-and-soci-pg15-pt4
# 3937                         tmx-table-7-2-1-element-interaction-with-the-proposed-pipeline-component-pg8-pt1
# 4342                                                      tmx-table-1-2-1-roles-and-responsibilities-pg19-pt1
# 4347                                                      tmx-table-1-2-1-roles-and-responsibilities-pg20-pt1
# 8464                                             2017ngtl-table-1-resource-specific-mitigation-table-pg19-pt1
# 8465                                             2017ngtl-table-1-resource-specific-mitigation-table-pg20-pt2
# 8466                                             2017ngtl-table-1-resource-specific-mitigation-table-pg21-pt3
# 8467                                             2017ngtl-table-1-resource-specific-mitigation-table-pg22-pt4
# 8468                                             2017ngtl-table-1-resource-specific-mitigation-table-pg23-pt5
# 8469                                             2017ngtl-table-1-resource-specific-mitigation-table-pg24-pt6
# 9079                                             2017ngtl-table-1-resource-specific-mitigation-table-pg18-pt1
# 9080                                             2017ngtl-table-1-resource-specific-mitigation-table-pg19-pt2
# 9141                                             2017ngtl-table-1-resource-specific-mitigation-table-pg20-pt1
# 9142                                             2017ngtl-table-1-resource-specific-mitigation-table-pg21-pt2
# 9143                                             2017ngtl-table-1-resource-specific-mitigation-table-pg22-pt3
# 9144                                             2017ngtl-table-1-resource-specific-mitigation-table-pg23-pt4
# 9145                                             2017ngtl-table-1-resource-specific-mitigation-table-pg24-pt5
# 9148                                             2017ngtl-table-1-resource-specific-mitigation-table-pg20-pt1
# 9149                                             2017ngtl-table-1-resource-specific-mitigation-table-pg21-pt2
# 9150                                             2017ngtl-table-1-resource-specific-mitigation-table-pg22-pt3
# 9151                                             2017ngtl-table-1-resource-specific-mitigation-table-pg23-pt4
# 9152                                             2017ngtl-table-1-resource-specific-mitigation-table-pg24-pt5
# 9153                                             2017ngtl-table-1-resource-specific-mitigation-table-pg25-pt6
# 9154                                             2017ngtl-table-1-resource-specific-mitigation-table-pg26-pt7
# 9155                                             2017ngtl-table-1-resource-specific-mitigation-table-pg27-pt8
# 9156                                             2017ngtl-table-1-resource-specific-mitigation-table-pg28-pt9
# 9157                                            2017ngtl-table-1-resource-specific-mitigation-table-pg29-pt10
# 10191                                                        nrgst-table-3-2-project-receptor-summary-pg6-pt1
# 10591                                                      nrgst-table-3-1-project-facility-locations-pg4-pt1
# 10785                                  nrgst-table-9-3-effects-classification-criteria--human-health-pg10-pt1
# 10786                                  nrgst-table-9-3-effects-classification-criteria--human-health-pg11-pt2
# 10792         nrgst-table-9-9-concentration-ratios-for-maximum-predicted-ground-level-concentrations-pg22-pt1
# 10794         nrgst-table-9-11-concentration-ratios-for-maximum-predicted-ground-level-concentration-pg23-pt1
# 10799                    nrgst-table-9-1-potential-effects-and-measurable-parameters-for-human-health-pg6-pt1
# 10800                                               nrgst-table-9-2-potential-effects-on-human-health-pg8-pt1
# 10801                                                         nrgst-table-1-1-pump-stations-in-québec-pg2-pt1
# 11348                   nrgst-table-8-12-recommended-mitigation-measures-for-vegetation-and-wetlands-pg24-pt1
# 11349                   nrgst-table-8-12-recommended-mitigation-measures-for-vegetation-and-wetlands-pg25-pt2
# 11350                   nrgst-table-8-12-recommended-mitigation-measures-for-vegetation-and-wetlands-pg26-pt3
# 11351                   nrgst-table-8-12-recommended-mitigation-measures-for-vegetation-and-wetlands-pg27-pt4
# 11376                                                        nrgst-table-1-1-pump-stations-in-alberta-pg2-pt1
# 11377                         nrgst-table-5-1-potential-effects-on-traditional-land-and-resource-use-pg18-pt1
# 11683                                     nrgst-table-5-2-potential-effects-on-groundwater-resources-pg12-pt1
# 11684                      nrgst-table-5-3-recommended-mitigation-measures-for-groundwater-resources-pg14-pt1
# 11688                          nrgst-table-5-6-potential-cumulative-effects-on-groundwater-resources-pg23-pt1
# 11689          nrgst-table-9-3-management-issues-for-selected-wildlife-species-of-management-concern-pg10-pt1
# 11690          nrgst-table-9-3-management-issues-for-selected-wildlife-species-of-management-concern-pg11-pt2
# 14453         nrgst-table-b-4-recommended-restricted-activity-periods-and-setback-distances-for-bird-pg63-pt1
# 14454         nrgst-table-b-4-recommended-restricted-activity-periods-and-setback-distances-for-bird-pg64-pt2
# 14455         nrgst-table-b-5-recommended-restricted-activity-periods-and-setback-distances-for-bird-pg64-pt1
# 14456         nrgst-table-b-5-recommended-restricted-activity-periods-and-setback-distances-for-bird-pg65-pt2
# 14457         nrgst-table-b-5-recommended-restricted-activity-periods-and-setback-distances-for-bird-pg66-pt3
# 14458                           nrgst-table-b-6-critical-breeding-season-for-raptor-species--ontario-pg66-pt1
# 14459                           nrgst-table-b-6-critical-breeding-season-for-raptor-species--ontario-pg67-pt2
# 14460         nrgst-table-b-7-recommended-restricted-activity-periods-and-setback-distances-for-rapt-pg67-pt1
# 14461         nrgst-table-b-8-recommended-restricted-activity-periods-and-setback-distances-for-bird-pg68-pt1
# 14462                                        nrgst-table-1-1-amphibian-species-of-management-concern-pg77-pt1
# 14463                                                nrgst-table-d-1-habitat-units-for-small-streams-pg11-pt1
# 14464                                                nrgst-table-d-1-habitat-units-for-small-streams-pg12-pt2
# 14465                                             nrgst-table-d-2-substrate-for-stream-bed-and-banks-pg13-pt1
# 14466                                            nrgst-table-d-3-embeddedness-code-class-description-pg13-pt1
# 14467                                                                 nrgst-table-d-4-bank-stability-pg13-pt1
# 14468                                                            nrgst-table-d-5-riparian-vegetation-pg14-pt1
# 14469                                                                nrgst-table-d-6-channel-pattern-pg14-pt1
# 14470                                                                nrgst-table-d-7-island-patterns-pg14-pt1
# 14471                                                          nrgst-table-d-8-sediment-bar-patterns-pg15-pt1
# 14472                                                              nrgst-table-d-9-coupling-patterns-pg15-pt1
# 14473                                             nrgst-table-d-10-confinement-code-type-description-pg15-pt1
# 14474                                             nrgst-table-d-11-channel-and-flow-characterization-pg16-pt1
# 14475                                                                    nrgst-table-d-12-flow-stage-pg16-pt1
# 14476                                                     nrgst-table-d-13-equipment-code-definition-pg16-pt1
# 14477                                      nrgst-table-d-14-species-code-common-name-scientific-name-pg17-pt1
# 14679                                                               nrgst-table-3-1-climate-stations-pg13-pt1
# 14699                                                               nrgst-table-3-1-climate-stations-pg15-pt1
# 14755                                             nrgst-table-2-3-agricultural-capability-subclasses-pg18-pt1
# 14757                                                         nrgst-table-2-4-compaction-risk-matrix-pg19-pt1
# 14759                                                      nrgst-table-2-6-wind-erosion-risk-classes-pg21-pt1
# 14764                              nrgst-table-3-1-agricultural-capability-extent---new-pipeline-row-pg28-pt1
# 14770                                           nrgst-table-a-1-soil-unit-extents---new-pipeline-row-pg39-pt1
# 14924                                                     nrgst-table-3-4-spill-volumes-by-frequency-pg12-pt1
# 14925                                                           nrgst-table-3-5-larger-spill-volumes-pg14-pt1
# 14926                                                           nrgst-table-3-5-larger-spill-volumes-pg15-pt2
# 14927                           nrgst-table-3-1-types-of-accidents-and-key-mitigation-for-oil-tankers-pg5-pt1
# 14928                   nrgst-table-3-2-predicted-annual-frequency-of-crude-oil-spill-from-collisions-pg7-pt1
# 14929          nrgst-table-3-3-predicted-annual-frequency-of-crude-oil-spill-resulting-from-grounding-pg8-pt1
# 16402       sprcrdg-table-4-3-base-case-dispersion-modelling-results-for-the-critical-levels-assessm-pg30-pt1
# 16458       sprcrdg-table-3-1-species-of-management-concern-known-or-likely-to-occur-within-the-regi-pg10-pt1
# 16459       sprcrdg-table-3-1-species-of-management-concern-known-or-likely-to-occur-within-the-regi-pg11-pt2
# 18507    nrthcrrdr-table-1-potential-access-management-measures-type-of-measure-specifications-comm-pg193-pt1
# 18508    nrthcrrdr-table-1-potential-access-management-measures-type-of-measure-specifications-comm-pg194-pt2
# 18509    nrthcrrdr-table-1-potential-access-management-measures-type-of-measure-specifications-comm-pg195-pt3
# 18510    nrthcrrdr-table-1-potential-access-management-measures-type-of-measure-specifications-comm-pg196-pt4
# 18511                                         nrthcrrdr-table-1-project-specific-mitigation-measures-pg20-pt1
# 28676                    dmntnhrdst-table-1--basic-night-time-sound-levels-as-per-ercb-directive-038-pg14-pt1
# 28679                 dmntnhrdst-table-4--calibration-case-modeled-results-at-noise-monitor-location-pg17-pt1
# 28680                                         dmntnhrdst-table-5--baseline-case-modeled-sound-levels-pg17-pt1
# 28681                             dmntnhrdst-table-6--baseline-case-modeled-dba-and-dbc-sound-levels-pg18-pt1
# 28682                                       dmntnhrdst-table-7--cumulative-case-modeled-sound-levels-pg19-pt1
# 28683                           dmntnhrdst-table-8--cumulative-case-modeled-dba-and-dbc-sound-levels-pg20-pt1
# Name: filename, dtype: object

# %%
df_FRA['nom_du_fichier'].duplicated().sum()
# Out:
# 402

# %%
df['filename'] = df['filename'] + '-' + 'no' + df['Index'].astype(str) + '.csv'

# %%
df_FRA['nom_du_fichier'] = df_FRA['nom_du_fichier'] + '-' + 'no' + df_FRA['Indice'].astype(str) + '.csv'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Indice'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-4ba048d16ffb> in <module>
# ----> 1 df_FRA['nom_du_fichier'] = df_FRA['nom_du_fichier'] + '-' + 'no' + df_FRA['Indice'].astype(str) + '.csv'
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Indice'

# %%
csv_folder_path = 'F:/Environmental Baseline Data/Version 4 - Final/all_csvs_cleaned_latest/'

# %%
os.chdir(csv_folder_path)

# %%
# %%time
# If the final file has been renamed, it will skip the renaming loop
if os.path.isfile(df['old_filename'].iloc[-1]):
  #loop through the name and rename
    for index, row in df.iterrows():
        if os.path.isfile(row['old_filename']):
            shutil.move(row['old_filename'], row['filename'])
# Out:
# yes
# Wall time: 15.6 ms

# %%
os.chdir('F:/Environmental Baseline Data/Version 4 - Final/Indices/')

# %%
df.to_csv('ESA_website_ENG_' + strftime("%Y_%m_%d", gmtime()) + '.csv')

# %%
df_FRA.to_csv('ESA_website_FRA_' + strftime("%Y_%m_%d", gmtime()) + '.csv', encoding='ISO-8859-1')

# %%
df_dup = pd.DataFrame([1, 2, 3, 1, 2, 2, 4])

# %%
df_dup.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# dtype: bool
