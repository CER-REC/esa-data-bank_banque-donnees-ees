# %% [markdown]
# # Copying tables from F or G drive to the esa-ees folder to put the files in production
#
# This notebook contains the necessary code to copy the ESA CSV files as well as the index files into the esa-ees folder. Once the files are in esa-ees, IT will take the files and copy them into the production / test folders.
#
# Part of the code organizes all the CSVs into their respective project folder. The files are then zipped into a zip file to make it easier for users to download the files.
#
# **What's missing?** There needs to be code added to bundle the files together. Personally, I would use a new duplicate folder of the csv files and test how you can bundle the files. Once you've bundled the files correctly, rearrange the code in this notebook as necessary.

# %%
#!pip install tqdm

# %%
import pandas as pd
import shutil # for copying files
from tqdm import tqdm # progress bar for for-loops
from zipfile import ZipFile # for creating zip files
import os
import glob

# %%
# filepath to the English and French index files
ENG_index_filepath = 'F:/Environmental Baseline Data/Version 4 - Final/Indices/ESA_website_ENG.csv'
FRA_index_filepath = 'F:/Environmental Baseline Data/Version 4 - Final/Indices/ESA_website_FRA.csv'

ENG_destination_path = "G:\\ESA_downloads\\esa_files_eng\\"

# %% [markdown]
# # Caution: Following code is to the delete files in esa-ees.
#
# Use this code when your are copying new files to esa-ees and you want to avoid creating duplicates with different filenames (or folder names).
#
# **Skip if you don't want to delete files in esa-ees.**

# %%
# %%time

# df = pd.read_csv(ENG_index_filepath)
# df['Download folder name'] = r'//dweb5/esa-ees/' + df['Download folder name'] + '/*'
# unique_folders = df['Download folder name'].unique()

# for x in tqdm(range(0, len(unique_folders))):
#     folder_name = unique_folders[x]
#     files = glob.glob(folder_name)
#     for f in files:
#         os.remove(f)
# Out:
# Wall time: 0 ns

# %% [markdown]
# ## Modifying index files with pandas to be able to copy files to esa-ees folder (the destination folder)

# %%
# %%time

# Loading index file of all tables
df = pd.read_csv(ENG_index_filepath)

# Grabbing project folder names and replacing with folder paths in esa-ees
df['Download Folder Name'] = r'//dweb5/esa-ees/' + df['Download folder name'] + '/'

# Creating new 
df['Csv Url'] = df["CSV Download URL"].str.split('/|_')

# Remove all rows for figures so that we are only moving tables
df = df[df['Content Type'] == 'Table']
df = df.reset_index(drop=True)
# Out:
# Wall time: 3min 10s

# %% [markdown]
# ### Checking a cell to see what the paths look like:

# %%
# df['Csv Path'][0]

# %%
# df['Download Folder Name'][0]

# %%
# df.head()

# %% [markdown]
# # 1. Table Level Downloads

# %% [markdown]
# # # Function to create about_me.txt

# %%
def create_table_about_me(path, about_me_data):
    f = open(path + "\\about_me.txt", "w+")
    text = "Guideline Limitation"
    text = text +'\r\n\t Please refer to the CER website\'s “Terms and Conditions" for limitations, which apply to this ESA Data Bank.'
    text = text +"\r\n Accuracy"
    text = text +"\r\n\t CSV table data is extracted according to the methods outlined in the Methodology Documentation and may contain some inaccuracies. Extracted data is limited to ESA filings submitted by companies at the start of the public hearing assessment process. ESA-related information that is filed after the initial application milestone is excluded from this collection. In the event of variance, the original PDF in REGDOCS is the main source. Data sources for ESA tables are cited at the discretion of the consultants writing the ESAs and may vary according to ESA. Figures and Tables are available in the language they were submitted in."
    text = text +"\r\n Citation"
    text = text +"\r\n\t To cite this data bank, please use the following"
    text = text +"\r\n\t Canada Energy Regulator (2020): Environmental and Socioeconomic Assessment Data Bank."
    text = text +"\r\n\t To cite individual data tables, please also cite the original ESA PDF in REGDOCS."
    text = text +"\r\n\t By choosing to download files, you understand these limitations."
    text = text +"\r\n Table Title: " + about_me_data[0] 
    text = text +"\r\n Application Name: " + about_me_data[1] 
    text = text +"\r\n Company Name: " + about_me_data[2] 
    text = text +"\r\n File Name: " + about_me_data[3] 
    
    f.write(text)
    f.close()

# %% [markdown]
# ## Copying the files from the source folder to the destination folder (esa-ees):

# %%
df = df.head(25)
df
# Out:
#     Unnamed: 0                                              Title  \
# 0            0  TABLE 3 SUMMARY OF AQUATICS FIELD WORK AND ABO...
# 1            1  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG...
# 2            2  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG...
# 3            3  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG...
# 4            4  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG...
# 5            5  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG...
# 6            6  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG...
# 7            7  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG...
# 8            8  TABLE 5 SUMMARY OF WATER QUALITY PARAMETERS AN...
# 9            9  TABLE 5 SUMMARY OF WATER QUALITY PARAMETERS AN...
# 10          10  TABLE 5 SUMMARY OF WATER QUALITY PARAMETERS AN...
# 11          11  TABLE 5 SUMMARY OF WATER QUALITY PARAMETERS AN...
# 12          12             TABLE 6 FISH HABITAT POTENTIAL RATINGS
# 13          13             TABLE 6 FISH HABITAT POTENTIAL RATINGS
# 14          14             TABLE 6 FISH HABITAT POTENTIAL RATINGS
# 15          15             TABLE 6 FISH HABITAT POTENTIAL RATINGS
# 16          16             TABLE 6 FISH HABITAT POTENTIAL RATINGS
# 17          17           TABLE 7 SUMMARY OF FISH SAMPLING RESULTS
# 18          18           TABLE 7 SUMMARY OF FISH SAMPLING RESULTS
# 19          19           TABLE 7 SUMMARY OF FISH SAMPLING RESULTS
# 20          20           TABLE 7 SUMMARY OF FISH SAMPLING RESULTS
# 21          21        TABLE 8 SUMMARY OF NON-CLASSIFIED DRAINAGES
# 22          22        TABLE 8 SUMMARY OF NON-CLASSIFIED DRAINAGES
# 23          23             Table 6 Fish Habitat Potential Ratings
# 24          24             Table 6 Fish Habitat Potential Ratings
#
#    Content Type                       Application Name Application Short Name  \
# 0         Table  Application for North Montney Project          North Montney
# 1         Table  Application for North Montney Project          North Montney
# 2         Table  Application for North Montney Project          North Montney
# 3         Table  Application for North Montney Project          North Montney
# 4         Table  Application for North Montney Project          North Montney
# 5         Table  Application for North Montney Project          North Montney
# 6         Table  Application for North Montney Project          North Montney
# 7         Table  Application for North Montney Project          North Montney
# 8         Table  Application for North Montney Project          North Montney
# 9         Table  Application for North Montney Project          North Montney
# 10        Table  Application for North Montney Project          North Montney
# 11        Table  Application for North Montney Project          North Montney
# 12        Table  Application for North Montney Project          North Montney
# 13        Table  Application for North Montney Project          North Montney
# 14        Table  Application for North Montney Project          North Montney
# 15        Table  Application for North Montney Project          North Montney
# 16        Table  Application for North Montney Project          North Montney
# 17        Table  Application for North Montney Project          North Montney
# 18        Table  Application for North Montney Project          North Montney
# 19        Table  Application for North Montney Project          North Montney
# 20        Table  Application for North Montney Project          North Montney
# 21        Table  Application for North Montney Project          North Montney
# 22        Table  Application for North Montney Project          North Montney
# 23        Table  Application for North Montney Project          North Montney
# 24        Table  Application for North Montney Project          North Montney
#
#    Application Filing Date                Company Name Commodity  \
# 0               2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 1               2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 2               2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 3               2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 4               2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 5               2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 6               2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 7               2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 8               2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 9               2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 10              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 11              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 12              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 13              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 14              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 15              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 16              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 17              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 18              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 19              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 20              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 21              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 22              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 23              2013-11-08  NOVA Gas Transmission Ltd.       Gas
# 24              2013-11-08  NOVA Gas Transmission Ltd.       Gas
#
#                                  File Name  \
# 0   B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 1   B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 2   B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 3   B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 4   B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 5   B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 6   B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 7   B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 8   B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 9   B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 10  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 11  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 12  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 13  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 14  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 15  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 16  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 17  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 18  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 19  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 20  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 21  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 22  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 23  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 24  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
#
#                                        ESA Folder URL  ...  \
# 0   https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 1   https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 2   https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 3   https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 4   https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 5   https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 6   https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 7   https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 8   https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 9   https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 10  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 11  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 12  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 13  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 14  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 15  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 16  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 17  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 18  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 19  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 20  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 21  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 22  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 23  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
# 24  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...  ...
#
#    ESA Section(s) Topics                                   CSV Download URL  \
# 0                  Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 1                  Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 2                  Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 3                  Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 4                  Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 5                  Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 6                  Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 7                  Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 8                  Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 9                  Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 10                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 11                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 12                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 13                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 14                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 15                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 16                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 17                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 18                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 19                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 20                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 21                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 22                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 23                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
# 24                 Water  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059...
#
#    PDF Page Number PDF Page Count PDF Size PDF Outline Download folder name  \
# 0               14           48.0     5.87          No             nrthmntn
# 1               17           48.0     5.87          No             nrthmntn
# 2               18           48.0     5.87          No             nrthmntn
# 3               19           48.0     5.87          No             nrthmntn
# 4               20           48.0     5.87          No             nrthmntn
# 5               21           48.0     5.87          No             nrthmntn
# 6               22           48.0     5.87          No             nrthmntn
# 7               23           48.0     5.87          No             nrthmntn
# 8               24           48.0     5.87          No             nrthmntn
# 9               25           48.0     5.87          No             nrthmntn
# 10              26           48.0     5.87          No             nrthmntn
# 11              27           48.0     5.87          No             nrthmntn
# 12              28           48.0     5.87          No             nrthmntn
# 13              29           48.0     5.87          No             nrthmntn
# 14              30           48.0     5.87          No             nrthmntn
# 15              31           48.0     5.87          No             nrthmntn
# 16              32           48.0     5.87          No             nrthmntn
# 17              33           48.0     5.87          No             nrthmntn
# 18              34           48.0     5.87          No             nrthmntn
# 19              35           48.0     5.87          No             nrthmntn
# 20              36           48.0     5.87          No             nrthmntn
# 21              37           48.0     5.87          No             nrthmntn
# 22              38           48.0     5.87          No             nrthmntn
# 23              45           48.0     5.87          No             nrthmntn
# 24              46           48.0     5.87          No             nrthmntn
#
#                               Zipped Project Link       Download Folder Name  \
# 0   http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 1   http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 2   http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 3   http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 4   http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 5   http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 6   http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 7   http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 8   http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 9   http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 10  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 11  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 12  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 13  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 14  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 15  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 16  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 17  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 18  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 19  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 20  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 21  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 22  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 23  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
# 24  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip  //dweb5/esa-ees/nrthmntn/
#
#                                               Csv Url
# 0   [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 1   [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 2   [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 3   [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 4   [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 5   [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 6   [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 7   [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 8   [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 9   [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 10  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 11  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 12  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 13  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 14  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 15  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 16  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 17  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 18  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 19  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 20  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 21  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 22  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 23  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
# 24  [http:, , www.cer-rec.gc.ca, esa-ees, nrthmntn...
#
# [25 rows x 33 columns]

# %%
# Adding source and destination filepaths to the dataframe
source_folder_path = 'F:/Environmental Baseline Data/Version 4 - Final/all_csvs_cleaned/'
source_filenames = []
dest_filenames = []

exceptions = []
source_file_names = []
source_title_names = []



previous_table_title = ""
for index, row in df.iterrows():
    if previous_table_title != row['Title'] and previous_table_title != "":
        
        #create the folder location 
        path = ENG_destination_path + 'tables\\'+ previous_table_title[:100]
        #path = os.path.realpath(ENG_destination_path + 'tables\\'+ previous_table_title[:25]
        try:
            os.mkdir(path)
        except OSError:
            print ("Creation of the directory %s failed" % path)
        
        #copy the csv files 
        for i in range(len(source_file_names)):
            try: 
            # copying the files into the destination folder
                shutil.copy(source_file_names[i], path +"\\" + source_title_names[i][:100]+"_" +str(i)+".csv")
            except:
                exceptions.append(row['Title'])
                print("exception raised on ", row['Title'])
                pass
        
        source_file_names = []
        source_title_names = []
            
        #create the about_me text file
        create_table_about_me(path, about_me_data)
            
        
    
    else:
        source_file_name = source_folder_path + row['Csv Url'][-3] + '_' + row['Csv Url'][-2] + '_lattice-v_' + row['Csv Url'][-1][0] + '.csv'
        source_file_names.append(source_file_name)
        source_title_names.append(row['Title'])
        
        about_me_data = [row['Title'], row['Application Name'], row['Company Name'], row['File Name']]
    
    previous_table_title = row['Title']

    
#Copy the above code to execute the last row tabel dump


print(len(source_file_names))
print(len(source_title_names))
# Out:
# 1
# 1

# %%
# Checking to see if we were able to move every single file
# 'exceptions' will be empty if so
exceptions
# Out:
# []

# %% [markdown]
# ## Saving the index files as individual zip files

# %%
ENG_website_filename = 'ESA_website_ENG.csv'
FRA_website_filename = 'ESA_website_FRA.csv'

# %% [markdown]
# **Note: The next coding block may need to include a duplicate for the French index file. Please contact Angelsea for info on how she would like the files to be saved. This is likely the case so I've duplicated the code for the French file as well. Delete if unnecessary.**
#
# Another thing, you may need to zip some other files as well, I'm unsure.

# %%
# %%time

# Loading ENG index file
df = pd.read_csv(ENG_index_filepath)

# Removing rows for the figures
df = df[df['Content Type'] == 'Table']

# destination path
dest_path = r'//dweb5/esa-ees/'

df.to_csv(dest_path + ENG_website_filename)

# Create a ZipFile object
zipObj = ZipFile('DLD-ndc.zip', 'w')

# Add multiple files to the zip by using zipObj.write(...) for each file/folder you want to include in the zip folder.
zipObj.write(dest_path + ENG_website_filename)
                 
# Close the Zip File
zipObj.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <timed exec> in <module>
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'F:/Environmental Baseline Data/Version 4 - Final/Indices/ESA_website_ENG.csv' does not exist: b'F:/Environmental Baseline Data/Version 4 - Final/Indices/ESA_website_ENG.csv'

# %% [markdown]
# ## Create a csv and excel file the download paths for each csv (separated by folder)

# %%
# English files

# %%time

# Loading ENG index file
df = pd.read_csv(ENG_index_filepath)

# Removing rows for the figures
df = df[df['Content Type'] == 'Table']

unique_folders = df['Download folder name'].unique()
download_folder_path_df = r'//dweb5/esa-ees/' + unique_folders + '/'

exceptions = []

for x in tqdm(range(0, len(unique_folders))):
    try:
        # Get name of the folder of a project
        folder_name = unique_folders[x]
        
        # Filter out all rows that aren't associated with project folder x
        folder_df = df[df['Download folder name'] == folder_name]
        
        # Save download path csv and excel files
        folder_df.to_csv(download_folder_path_df[x] + folder_name + '_ENG.csv')
        folder_df.to_excel(download_folder_path_df[x] + folder_name + '_ENG.xlsx')
    except:
        pass
        exceptions.append(df['Download folder name'].iloc[x])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 38/38 [00:58<00:00,  1.53s/it]
# Wall time: 1min

# %%
## Same as above, but for the French files

# %%time

df = pd.read_csv(FRA_index_filepath)
df = df[df['Type de contenu'] == 'Tableau']
dossiers_uniques = df['Télécharger le nom du dossier'].unique()
download_folder_path_df = r'//dweb5/esa-ees/' + dossiers_uniques + '/'

exceptions = []

for x in tqdm(range(0, len(dossiers_uniques))):
    try:
        # Get name of the folder of a project
        nom_du_dossier = dossiers_uniques[x]
        
        # Filter out all rows that aren't associated with project folder x
        dossier_df = df[df['Télécharger le nom du dossier'] == nom_du_dossier]
        
        # Save download path csv and excel files
        dossier_df.to_csv(download_folder_path_df[x] + nom_du_dossier + '_FRA.csv')
        dossier_df.to_excel(download_folder_path_df[x] + nom_du_dossier + '_FRA.xlsx')
    except:
        pass
        exceptions.append(df['Télécharger le nom du dossier'].iloc[x])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 37/37 [00:58<00:00,  1.59s/it]
# Wall time: 59.8 s

# %% [markdown]
# ## Create a zip file of each individual project folder

# %%
# %%time

df = pd.read_csv(ENG_index_filepath)
unique_folders = df['Download folder name'].unique()
folder_paths = r'//dweb5/esa-ees/' + unique_folders

exceptions = []

for x in tqdm(range(0, len(unique_folders))):
    try:
        shutil.make_archive(folder_paths[x], 'zip', folder_paths[x])
    except:
        pass
        exceptions.append(folder_paths[x])
