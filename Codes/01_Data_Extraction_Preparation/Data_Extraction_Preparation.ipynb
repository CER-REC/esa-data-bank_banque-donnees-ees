# %% [markdown]
# # Environmental and Social-Economic Assessment (ESA) Dataset

# %% [markdown]
# On 1 May 2020, the Canadian Energy Regulator (CER) published the [ESD Data Bank](https://apps.cer-rec.gc.ca/REGDOCS/Home/Index/FAKE), an interactive tool that allows users to visualize, download, and share ESA data from applications filed in support of federally regulated pipeline projects. The tools contains 13,681 and 3,024 unique tables and figures from 37 pipeline projects submitted to the CER between 2003 and 2019 (output files). Data was extracted from 1,902 PDF documents available from the CER's public repository called [REGDOCS](https://apps.cer-rec.gc.ca/REGDOCS).  <br>
#
# To download individual tables (in CSV and JPG format) and figures (in JPG) format, see the [ESD Data Bank](https://apps.cer-rec.gc.ca/REGDOCS/Home/Index/FAKE) Data Bank online tool. The [ESA Data Bank](https://apps.cer-rec.gc.ca/REGDOCS/Home/Index) is an interactive tool that allows users to visualize, download, and share the Canada Energy Regulator’s (CER) ESA data from applications filed in support of federally regulated pipeline projects and related facilities. <br>
#
# This repo contains several python functions that create the ESA dataset and the figure and table output files. Data is extracted from PDF files submitted by pipeline companies. <br>
#
# This Notebooks provides a step by step guide to re-create the ESA Data Bank dataset. In total, 13,681 unique tables were extracted. Many tables span multiple pages, and thus the total number of extracted CSVs is 27,058. Figure data was saved as a unique JPG file. 3,024 figures were extracted in total.

# %% [markdown]
# # About the Code

# %% [markdown]
# Our assumption is that “Index of PDFs for Major Projects with ESAs” is already created.  We will implement the other pieces of codes with functions. The list of the functions are as follows: <br>
#
# 1.	Scrape PDF File<br>
#
# 2.	Rotate the PDF Files <br>
#
# 3.  Convert PDF to Tika Files <br>
#
# 4.	Convert rotated PDF Files to rotated TIKA Files
#
# 5. Extract PDF Metadata <br>
#
# Things which we are currently working on but which will be implemented in the Phase 2 of the project are:
# -	Index 3 – List of at CSV Files with Categories
# -	Index 4 – List of Images with Categories
# -	Index 5 – GIS Locations extracted for PDF Files
# -	Index 6 – Alignment Sheets extracted with geotags

# %% [markdown]
# # Installing the Required Packages

# %%
#importing standard packages

import pandas as pd
import time
import os
import sys
import requests
#from bs4 import BeautifulSoup as bs
#import wget
import re
from urllib.parse import unquote
import PyPDF2 as p2
import glob
import multiprocessing
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# importing custom functions 
import scraper
import rotate_pdfs
import pickles_functions_mp
import pdf_metadata

# %% [markdown]
# # Exploring the Input Files (Index of PDFs for Major Projects with ESAs)

# %%
Index0_path = os.path.realpath('..\\..') + "\\Input_Files\\Index_of_PDFs_for_Major_Projects_with_ESAs.csv"

Index0 = pd.read_csv(Index0_path, index_col = 0)
Index0.head()
Index0.info()
# Out:
#                                                                                      Application Name  \
# application_name
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
#
#                                                    Application Short Name  \
# application_name
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
#
#                                                    Application Filing Date  \
# application_name
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
#
#                                                                   Company Name  \
# application_name
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
#
#                                                    Commodity  \
# application_name
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
#
#                                                                                             File Name  \
# application_name
# 2003-03-17 Application to Construct and Operate...          A0H8C0 - 13.0 EIA - Section 13.1 to 13.6
# 2003-03-17 Application to Construct and Operate...   A0H8C1 - 13.0 EIA - Section 13.7 Wildlife Part 1
# 2003-03-17 Application to Construct and Operate...  A0H8C2 - 13.0 EIA - Section 13.7 Wildlife Part 2
# 2003-03-17 Application to Construct and Operate...          A0H8C3 - 13.0 EIA - Section 13.8 to 13.13
# 2003-03-17 Application to Construct and Operate...           A0H8C4 - 13.1 App 13A - Alignment Sheets
#
#                                                                                        ESA Folder URL  \
# application_name
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
#
#                                                    Document Number  Data ID  \
# application_name
# 2003-03-17 Application to Construct and Operate...          A0H8C0   268706
# 2003-03-17 Application to Construct and Operate...          A0H8C1   268709
# 2003-03-17 Application to Construct and Operate...          A0H8C2   268712
# 2003-03-17 Application to Construct and Operate...          A0H8C3   269018
# 2003-03-17 Application to Construct and Operate...          A0H8C4   269021
#
#                                                                                      PDF Download URL  \
# application_name
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
#
#                                                      Application Type (NEB Act)  \
# application_name
# 2003-03-17 Application to Construct and Operate...  Large Projects (over 40 km)
# 2003-03-17 Application to Construct and Operate...  Large Projects (over 40 km)
# 2003-03-17 Application to Construct and Operate...  Large Projects (over 40 km)
# 2003-03-17 Application to Construct and Operate...  Large Projects (over 40 km)
# 2003-03-17 Application to Construct and Operate...  Large Projects (over 40 km)
#
#                                                             Pipeline Location  \
# application_name
# 2003-03-17 Application to Construct and Operate...  Alberta, British Columbia
# 2003-03-17 Application to Construct and Operate...  Alberta, British Columbia
# 2003-03-17 Application to Construct and Operate...  Alberta, British Columbia
# 2003-03-17 Application to Construct and Operate...  Alberta, British Columbia
# 2003-03-17 Application to Construct and Operate...  Alberta, British Columbia
#
#                                                    Hearing order  \
# application_name
# 2003-03-17 Application to Construct and Operate...     GH-1-2003
# 2003-03-17 Application to Construct and Operate...     GH-1-2003
# 2003-03-17 Application to Construct and Operate...     GH-1-2003
# 2003-03-17 Application to Construct and Operate...     GH-1-2003
# 2003-03-17 Application to Construct and Operate...     GH-1-2003
#
#                                                                        Consultant Name  \
# application_name
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
#
#                                                    Pipeline Status  \
# application_name
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
#
#                                                    Regulatory Instrument(s)  \
# application_name
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
#
#                                                                                       Application URL  \
# application_name
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
#
#                                                                                          Decision URL  \
# application_name
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
#
#                                                                                        ESA Section(s)  \
# application_name
# 2003-03-17 Application to Construct and Operate...  Section 13.1: Introduction, Section 13.1: Proj...
# 2003-03-17 Application to Construct and Operate...        Section 13.7: Wildlife and Wildlife Habitat
# 2003-03-17 Application to Construct and Operate...        Section 13.7: Wildlife and Wildlife Habitat
# 2003-03-17 Application to Construct and Operate...  Section 13.8: Fisheries and Aquatic Resources,...
# 2003-03-17 Application to Construct and Operate...       Appendix 13A: Environmental Alignment Sheets
#
#                                                     ESA Section(s) Index
# application_name
# 2003-03-17 Application to Construct and Operate...                   1.0
# 2003-03-17 Application to Construct and Operate...                   2.0
# 2003-03-17 Application to Construct and Operate...                   3.0
# 2003-03-17 Application to Construct and Operate...                   4.0
# 2003-03-17 Application to Construct and Operate...                   5.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 1902 entries, 2003-03-17 Application to Construct and Operate Ekwan Pipeline GH-1-2003 to 2009-02-27 - Application for the Keystone XL Pipeline (OH-1-2009)
# Data columns (total 20 columns):
# Application Name              1902 non-null object
# Application Short Name        1902 non-null object
# Application Filing Date       1902 non-null object
# Company Name                  1902 non-null object
# Commodity                     1902 non-null object
# File Name                     1902 non-null object
# ESA Folder URL                1902 non-null object
# Document Number               1902 non-null object
# Data ID                       1902 non-null int64
# PDF Download URL              1902 non-null object
# Application Type (NEB Act)    1902 non-null object
# Pipeline Location             1902 non-null object
# Hearing order                 1902 non-null object
# Consultant Name               1902 non-null object
# Pipeline Status               1902 non-null object
# Regulatory Instrument(s)      1430 non-null object
# Application URL               1902 non-null object
# Decision URL                  1418 non-null object
# ESA Section(s)                1901 non-null object
# ESA Section(s) Index          1901 non-null float64
# dtypes: float64(1), int64(1), object(18)
# memory usage: 312.0+ KB

# %% [markdown]
# # 1. Scrape PDF Files

# %% [markdown]
# Scraping PDF Files from the URL liks in the Index0 dataframe.

# %%
# Limiting the number of files to 10 for a trial run
Index0 = Index0.head(10)
len(Index0)
# Out:
# 10

# %%
count = scraper.file_scraper(os.path.realpath('..\\..'), Index0)
print("{} Files were downloaded from {} URL links".format(count, len(Index0)))
# Out:
# 10 Files were downloaded from 10 URL links

# %% [markdown]
# # 2. Rotate the PDF Files

# %%
count = rotate_pdfs.rotate_pdf(os.path.realpath('..\\..'), Index0)
print("{} Files were rotaed successfully".format(count))
# Out:
# 10 Files were rotaed successfully

# %% [markdown]
# # 3. Convert PDFs to Tika Files

# %%
# list of full paths to pdfs
pdf_folder_path = os.path.realpath('..\\..') + '\\Data_Files\\PDFs\\'

subset_list_pdf_full = [pdf_folder_path
                        + x.split('\\')[-1] for x in glob.glob(pdf_folder_path + '*.pdf')]

# Directory where the output pickle files are saved
pkl_folder_path = os.path.realpath('..\\..') + '\\Data_Files\\Pickle_Files\\'
# prepare arguments for multiprocessing
args = pickles_functions_mp.get_argument(subset_list_pdf_full, pkl_folder_path)

# timing the process-start
starttime = time.time()

# #sequential
# for arg in args:
#     try:
#         pickles_functions_mp.pickle_pdf_xml(arg)
#     except Exception:
#         #print("exception was raised for {}".format(arg))
#         pass

# multiprocessing
pool = multiprocessing.Pool()
pool.map(pickles_functions_mp.pickle_pdf_xml, args)
pool.close()
#time ends and dellta displayed
print('That took {} seconds'.format(time.time() - starttime))
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Anaconda\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Anaconda\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Users\singvibu\Desktop\GitHub\CERdataESA\Codes\01_Data_Extraction_Preparation\pickles_functions_mp.py", line 22, in pickle_pdf_xml
#     xml = parser.from_file(file, xmlContent = True)
#   File "C:\Anaconda\lib\site-packages\tika\parser.py", line 39, in from_file
#     headers=headers, config_path=config_path, requestOptions=requestOptions)
#   File "C:\Anaconda\lib\site-packages\tika\tika.py", line 331, in parse1
#     rawResponse=rawResponse, requestOptions=requestOptions)
#   File "C:\Anaconda\lib\site-packages\tika\tika.py", line 524, in callServer
#     serverEndpoint = checkTikaServer(scheme, serverHost, port, tikaServerJar, classpath, config_path)
#   File "C:\Anaconda\lib\site-packages\tika\tika.py", line 594, in checkTikaServer
#     raise RuntimeError("Unable to start Tika server.")
# RuntimeError: Unable to start Tika server.
# """
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-d1af354ba965> in <module>
#      23 # multiprocessing
#      24 pool = multiprocessing.Pool()
# ---> 25 pool.map(pickles_functions_mp.pickle_pdf_xml, args)
#      26 pool.close()
#      27 #time ends and dellta displayed
#
# C:\Anaconda\lib\multiprocessing\pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# C:\Anaconda\lib\multiprocessing\pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# RuntimeError: Unable to start Tika server.

# %% [markdown]
# # 4. Convert Rotated PDFs to Rotated Tika Files

# %%
# list of full paths to roatted pdfs
pdf_folder_path = os.path.realpath('..\\..') + '\\Data_Files\\PDFs_Rotated\\'

subset_list_pdf_full = [pdf_folder_path
                        + x.split('\\')[-1] for x in glob.glob(pdf_folder_path + '*.pdf')]

# Directory where the output pickle files are saved
pkl_folder_path = os.path.realpath('..\\..') + '\\Data_Files\\Pickle_Files_Rotated\\'
# prepare arguments for multiprocessing
args = pickles_functions_mp.get_argument(subset_list_pdf_full, pkl_folder_path)

# timing the process-start
starttime = time.time()

# #sequential
# for arg in args:
#     try:
#         pickles_functions_mp.pickle_pdf_xml(arg)
#     except Exception:
#         #print("exception was raised for {}".format(arg))
#         pass

# multiprocessing
pool = multiprocessing.Pool()
pool.map(pickles_functions_mp.pickle_pdf_xml, args)
pool.close()
#time ends and dellta displayed
print('That took {} seconds'.format(time.time() - starttime))
# Out:
# [True, True, True, True, True, True, True, True, True, True]
# That took 7.190502643585205 seconds

# %% [markdown]
# # 5. Extracting PDF Metadata

# %%
Index1 = pdf_metadata.pdf_categorize(Index0_path, Index0)
Index1 = pdf_metadata.pdf_size(os.path.realpath('..\\..'), Index1)
Index1 = pdf_metadata.pdf_pagenumbers(os.path.realpath('..\\..'), Index1)
Index1
# Out:
#                                                                                      Application Name  \
# application_name
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
# 2003-03-17 Application to Construct and Operate...  Application to Construct and Operate Ekwan Pip...
#
#                                                    Application Short Name  \
# application_name
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
# 2003-03-17 Application to Construct and Operate...                  Ekwan
#
#                                                    Application Filing Date  \
# application_name
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
# 2003-03-17 Application to Construct and Operate...              2003-03-17
#
#                                                                   Company Name  \
# application_name
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
# 2003-03-17 Application to Construct and Operate...  EnCana Ekwan Pipeline Inc.
#
#                                                    Commodity  \
# application_name
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
# 2003-03-17 Application to Construct and Operate...       Gas
#
#                                                                                             File Name  \
# application_name
# 2003-03-17 Application to Construct and Operate...          A0H8C0 - 13.0 EIA - Section 13.1 to 13.6
# 2003-03-17 Application to Construct and Operate...   A0H8C1 - 13.0 EIA - Section 13.7 Wildlife Part 1
# 2003-03-17 Application to Construct and Operate...  A0H8C2 - 13.0 EIA - Section 13.7 Wildlife Part 2
# 2003-03-17 Application to Construct and Operate...          A0H8C3 - 13.0 EIA - Section 13.8 to 13.13
# 2003-03-17 Application to Construct and Operate...           A0H8C4 - 13.1 App 13A - Alignment Sheets
# 2003-03-17 Application to Construct and Operate...            A0H8C5 - 13.2 App 13B - NEB Concordance
# 2003-03-17 Application to Construct and Operate...      A0H8C6 - 13.3 App 13C - CEAA 16.1 Concordance
# 2003-03-17 Application to Construct and Operate...                        A0H8C7 - 13.4 App 13D - EPP
# 2003-03-17 Application to Construct and Operate...         A0H8C8 - 13.4 App 13D.A - Typical Drawings
# 2003-03-17 Application to Construct and Operate...     A0H8C9 - 13.4 App 13D.B - Watercouse Crossings
#
#                                                                                        ESA Folder URL  \
# application_name
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadRe...
#
#                                                    Document Number  Data ID  \
# application_name
# 2003-03-17 Application to Construct and Operate...          A0H8C0   268706
# 2003-03-17 Application to Construct and Operate...          A0H8C1   268709
# 2003-03-17 Application to Construct and Operate...          A0H8C2   268712
# 2003-03-17 Application to Construct and Operate...          A0H8C3   269018
# 2003-03-17 Application to Construct and Operate...          A0H8C4   269021
# 2003-03-17 Application to Construct and Operate...          A0H8C5   269024
# 2003-03-17 Application to Construct and Operate...          A0H8C6   269027
# 2003-03-17 Application to Construct and Operate...          A0H8C7   269030
# 2003-03-17 Application to Construct and Operate...          A0H8C8   269033
# 2003-03-17 Application to Construct and Operate...          A0H8C9   268930
#
#                                                                                      PDF Download URL  \
# application_name
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/File/Downlo...
#
#                                                     ...  \
# application_name                                    ...
# 2003-03-17 Application to Construct and Operate...  ...
# 2003-03-17 Application to Construct and Operate...  ...
# 2003-03-17 Application to Construct and Operate...  ...
# 2003-03-17 Application to Construct and Operate...  ...
# 2003-03-17 Application to Construct and Operate...  ...
# 2003-03-17 Application to Construct and Operate...  ...
# 2003-03-17 Application to Construct and Operate...  ...
# 2003-03-17 Application to Construct and Operate...  ...
# 2003-03-17 Application to Construct and Operate...  ...
# 2003-03-17 Application to Construct and Operate...  ...
#
#                                                                        Consultant Name  \
# application_name
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
# 2003-03-17 Application to Construct and Operate...  AXYS Environmental Consulting Ltd.
#
#                                                    Pipeline Status  \
# application_name
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
# 2003-03-17 Application to Construct and Operate...       Operating
#
#                                                    Regulatory Instrument(s)  \
# application_name
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
# 2003-03-17 Application to Construct and Operate...                   GC-108
#
#                                                                                       Application URL  \
# application_name
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
#
#                                                                                          Decision URL  \
# application_name
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
# 2003-03-17 Application to Construct and Operate...  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/2...
#
#                                                                                        ESA Section(s)  \
# application_name
# 2003-03-17 Application to Construct and Operate...  Section 13.1: Introduction, Section 13.1: Proj...
# 2003-03-17 Application to Construct and Operate...        Section 13.7: Wildlife and Wildlife Habitat
# 2003-03-17 Application to Construct and Operate...        Section 13.7: Wildlife and Wildlife Habitat
# 2003-03-17 Application to Construct and Operate...  Section 13.8: Fisheries and Aquatic Resources,...
# 2003-03-17 Application to Construct and Operate...       Appendix 13A: Environmental Alignment Sheets
# 2003-03-17 Application to Construct and Operate...  Appendix 13B: NEB Guidelines for Filing Requir...
# 2003-03-17 Application to Construct and Operate...  Appendix 13C: CEAA Section 16(1) Concordance T...
# 2003-03-17 Application to Construct and Operate...        Appendix 13D: Environmental Protection Plan
# 2003-03-17 Application to Construct and Operate...        Appendix 13D: Environmental Protection Plan
# 2003-03-17 Application to Construct and Operate...        Appendix 13D: Environmental Protection Plan
#
#                                                    ESA Section(s) Index  \
# application_name
# 2003-03-17 Application to Construct and Operate...                  1.0
# 2003-03-17 Application to Construct and Operate...                  2.0
# 2003-03-17 Application to Construct and Operate...                  3.0
# 2003-03-17 Application to Construct and Operate...                  4.0
# 2003-03-17 Application to Construct and Operate...                  5.0
# 2003-03-17 Application to Construct and Operate...                  6.0
# 2003-03-17 Application to Construct and Operate...                  7.0
# 2003-03-17 Application to Construct and Operate...                  8.0
# 2003-03-17 Application to Construct and Operate...                  9.0
# 2003-03-17 Application to Construct and Operate...                 10.0
#
#                                                                                   Topics  \
# application_name
# 2003-03-17 Application to Construct and Operate...               [Land, Air, Vegetation]
# 2003-03-17 Application to Construct and Operate...                            [Wildlife]
# 2003-03-17 Application to Construct and Operate...                            [Wildlife]
# 2003-03-17 Application to Construct and Operate...        [Land, Water, Wildlife, Human]
# 2003-03-17 Application to Construct and Operate...                     [Alignment Sheet]
# 2003-03-17 Application to Construct and Operate...                               [Other]
# 2003-03-17 Application to Construct and Operate...                               [Other]
# 2003-03-17 Application to Construct and Operate...         [Environment Protection Plan]
# 2003-03-17 Application to Construct and Operate...         [Environment Protection Plan]
# 2003-03-17 Application to Construct and Operate...  [Water, Environment Protection Plan]
#
#                                                    PDF Size (bytes)  \
# application_name
# 2003-03-17 Application to Construct and Operate...          1483221
# 2003-03-17 Application to Construct and Operate...          4544963
# 2003-03-17 Application to Construct and Operate...          4369127
# 2003-03-17 Application to Construct and Operate...          2180117
# 2003-03-17 Application to Construct and Operate...          3266671
# 2003-03-17 Application to Construct and Operate...           152004
# 2003-03-17 Application to Construct and Operate...            68333
# 2003-03-17 Application to Construct and Operate...           242261
# 2003-03-17 Application to Construct and Operate...          4036880
# 2003-03-17 Application to Construct and Operate...          2639960
#
#                                                     Number of Pages
# application_name
# 2003-03-17 Application to Construct and Operate...              107
# 2003-03-17 Application to Construct and Operate...               39
# 2003-03-17 Application to Construct and Operate...               27
# 2003-03-17 Application to Construct and Operate...               84
# 2003-03-17 Application to Construct and Operate...               15
# 2003-03-17 Application to Construct and Operate...               16
# 2003-03-17 Application to Construct and Operate...                3
# 2003-03-17 Application to Construct and Operate...               35
# 2003-03-17 Application to Construct and Operate...               28
# 2003-03-17 Application to Construct and Operate...               27
#
# [10 rows x 23 columns]
