# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-24-edf619d7b45c>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
old_df = pd.read_csv('./mydata/esa_index_keyword_labeled_2021-09-07_12-29-08.csv', encoding='utf-8', index_col=0)
latest_df = pd.read_csv('./mydata/ESA_website_ENG.csv', encoding='utf-8')
# Out:
# C:\Users\ThibJacq\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (26,27,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
old_df.head()
# Out:
#    Index                                              Title Content Type  \
# 0   9134  TABLE 3 SUMMARY OF AQUATICS FIELD WORK AND ABO...        Table
# 1   9135  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG...        Table
# 2   9136  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG...        Table
# 3   9137  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG...        Table
# 4   9138  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG...        Table
#
#                         Application Name Application Short Name  \
# 0  Application for North Montney Project          North Montney
# 1  Application for North Montney Project          North Montney
# 2  Application for North Montney Project          North Montney
# 3  Application for North Montney Project          North Montney
# 4  Application for North Montney Project          North Montney
#
#   Application Filing Date                Company Name Commodity  \
# 0               11/8/2013  NOVA Gas Transmission Ltd.       Gas
# ...

# %%
latest_df.Title.iloc[0:1000]
# Out:
# 0      TABLE 1 HYDROMETRIC DATA FROM DISCHARGE STATIONS IN THE VICINITY OF THE PROPOSED AITKEN CREEK SECTION
# 1      TABLE 2 FISH SPECIES THAT MAY OCCUR IN THE UPPER PEACE RIVER BASIN IN THE VICINITY OF THE PROPOSED PIPELINE ROUTE
# 2      TABLE 3 SUMMARY OF AQUATICS FIELD WORK AND ABORIGINAL FIELD STUDY PARTICIPATION FOR THE PROJECT
# 3      TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 4      TABLE 5 SUMMARY OF WATER QUALITY PARAMETERS AND MEAN CHANNEL CHARACTERISTICS
# 5      TABLE 6 FISH HABITAT POTENTIAL RATINGS
# 6      TABLE 7 SUMMARY OF FISH SAMPLING RESULTS
# 7      TABLE 8 SUMMARY OF NON-CLASSIFIED DRAINAGES
# 8      Table 6 Fish Habitat Potential Ratings
# 9      Table 3-1 Wildlife Species of Management Concern in the RAA
# 10     Table 3-2 EOSD Vegetation Cover Classes and Project Definitions
# 11     Table 3-3 Species-Habitat Associations Used to Determine Availability of Suitable Habitat
# ...

# %%
latest_df.iloc[650:660]
# Out:
#                                                                          Title  \
# 650  TABLE 5.4.3-5 SACRED SITES IDENTIFIED BY SHXW’ŌWHÁMEL FIRST NATION
# 651  TABLE 5.4.8-1 PLANT GATHERING SITES IDENTIFIED BY POPKUM FIRST NATION
# 652  TABLE 5.4.8-2 HUNTING SITES IDENTIFIED BY POPKUM FIRST NATION
# 653  TABLE 5.4.8-3 FISHING SITES IDENTIFIED BY POPKUM FIRST NATION
# 654  TABLE 5.4.8-4 SACRED AREAS IDENTIFIED BY POPKUM FIRST NATION
# 655  TABLE 5.4.19-1 TRAILS AND TRAVELWAYS IDENTIFIED BY LEQ’Á:MEL FIRST NATION
# 656  TABLE 5.4.19-2 HABITATION SITES IDENTIFIED BY LEQ’Á:MEL FIRST NATION
# 657  TABLE 5.4.19-3 PLANT GATHERING SITES IDENTIFIED BY LEQ’Á:MEL FIRST NATION
# 658  TABLE 5.4.19-4 HUNTING SITES IDENTIFIED BY LEQ’Á:MEL FIRST NATION
# 659  TABLE 5.4.19-5 FISHING SITES IDENTIFIED BY LEQ’Á:MEL FIRST NATION
#
#     Content Type                                  Application Name  \
# 650  Table        Application for Trans Mountain Expansion Project
# ...

# %%
latest_df.ID.dtype
# Out:
# dtype('int64')
