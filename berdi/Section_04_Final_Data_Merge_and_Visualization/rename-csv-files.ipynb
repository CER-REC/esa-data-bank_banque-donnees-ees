# %% [markdown]
# # Renaming CSV Files
#
# This notebook renames the CSV files of the ESA project. The filenames in the SQL database are not very descriptive, therefore it was important to change the filenames for a better user experience.
#
# The current filenames look something like this: 1059614_14_lattice-v_1.csv
#
# In this notebook, we will rename them to something like: nrthmntn_table-3-summary-of-aquatics-field-work-and-aborigi_pt-1_pg-14_doc-num-A3Q6H2.csv
#
# The new filename contains the following information:
#
# - Short Name of Project (Ex: nrthmntn)
# - Table Title of the extracted table (Ex: table-3-summary-of-aquatics-field-work-and-aborigi; length of title is shortened to keep filepath under 256 characters)
# - The Part of the table (we have a counter for each additional CSV of a particular table)
# - Page Number of the extracted CSV
# - Document Number of the particular PDF

# %%
import pandas as pd
import os
import glob
import shutil
from time import localtime, strftime

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_colwidth', 255)

# %%
# filepath to the English and French index files
ENG_index_filepath = 'F:/Environmental Baseline Data/Version 4 - Final/Indices/ESA_website_ENG_03032021.csv'
# FRA_index_filepath = 'F:/Environmental Baseline Data/Version 4 - Final/Indices/ESA_website_FRA_titles_sections_translated.xlsx'
FRA_index_filepath = 'F:/Environmental Baseline Data/Version 4 - Final/Indices/ESA_website_FRA_03032021.csv'

# %%
# Loading index file of all tables
df = pd.read_csv(ENG_index_filepath, encoding='ISO-8859-1')
# df_FRA = pd.read_excel(FRA_index_filepath)
df_FRA = pd.read_csv(FRA_index_filepath, encoding='ISO-8859-1')

# %%
df.head()
# Out:
#                                                                                                                                              Title  \
# 0                                                                                                              Figure 13.1-1 EnCana Ekwan Pipeline
# 1                                                                                                                      Figure 13.3-1 CEA Framework
# 2                                                Figure 13.4-1 Temperature Normals Measured at the Fort Nelson Airport for the Period 1971 to 2000
# 3  Figure 13.4-2 Mean Monthly Rainfall and Number of Days with Measurable Rainfall Observed at the Fort Nelson Airport for the Period 1971 to 2000
# 4  Figure 13.4-3 Mean Monthly Snowfall and Number of Days with Measurable Snowfall Observed at the Fort Nelson Airport for the Period 1971 to 2000
#
#   Content Type                                     Application Name  \
# 0       Figure  Application to Construct and Operate Ekwan Pipeline
# 1       Figure  Application to Construct and Operate Ekwan Pipeline
# 2       Figure  Application to Construct and Operate Ekwan Pipeline
# 3       Figure  Application to Construct and Operate Ekwan Pipeline
# 4       Figure  Application to Construct and Operate Ekwan Pipeline
#
#   Application Short Name Application Filing Date                Company Name  \
# 0                  Ekwan               3/17/2003  EnCana Ekwan Pipeline Inc.
# 1                  Ekwan               3/17/2003  EnCana Ekwan Pipeline Inc.
# 2                  Ekwan               3/17/2003  EnCana Ekwan Pipeline Inc.
# 3                  Ekwan               3/17/2003  EnCana Ekwan Pipeline Inc.
# 4                  Ekwan               3/17/2003  EnCana Ekwan Pipeline Inc.
#
#   Commodity                                  File Name  \
# 0       Gas  A0H8C0 - 13.0 EIA - Section 13.1 to 13.6
# 1       Gas  A0H8C0 - 13.0 EIA - Section 13.1 to 13.6
# 2       Gas  A0H8C0 - 13.0 EIA - Section 13.1 to 13.6
# 3       Gas  A0H8C0 - 13.0 EIA - Section 13.1 to 13.6
# 4       Gas  A0H8C0 - 13.0 EIA - Section 13.1 to 13.6
#
#                                               ESA Folder URL Document Number  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/268693          A0H8C0
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/268693          A0H8C0
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/268693          A0H8C0
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/268693          A0H8C0
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/268693          A0H8C0
#
#    Data ID                                         PDF Download URL  \
# 0   268706  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/268706
# 1   268706  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/268706
# 2   268706  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/268706
# 3   268706  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/268706
# 4   268706  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/268706
#
#     Application Type (NEB Act)               Pipeline Location Hearing order  \
# 0  Large Projects (over 40 km)  Alberta, British Columbia, All     GH-1-2003
# 1  Large Projects (over 40 km)  Alberta, British Columbia, All     GH-1-2003
# 2  Large Projects (over 40 km)  Alberta, British Columbia, All     GH-1-2003
# 3  Large Projects (over 40 km)  Alberta, British Columbia, All     GH-1-2003
# 4  Large Projects (over 40 km)  Alberta, British Columbia, All     GH-1-2003
#
#                       Consultant Name Pipeline Status  \
# 0  AXYS Environmental Consulting Ltd.       Operating
# 1  AXYS Environmental Consulting Ltd.       Operating
# 2  AXYS Environmental Consulting Ltd.       Operating
# 3  AXYS Environmental Consulting Ltd.       Operating
# 4  AXYS Environmental Consulting Ltd.       Operating
#
#   Regulatory Instrument(s)  \
# 0                   GC-108
# 1                   GC-108
# 2                   GC-108
# 3                   GC-108
# 4                   GC-108
#
#                                        Application URL  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/268876
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/268876
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/268876
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/268876
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/268876
#
#                                           Decision URL  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/293763
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/293763
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/293763
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/293763
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/293763
#
#                                                                                                                                                                   ESA Section(s)  \
# 0  Section 13.1: Introduction, Section 13.2: Project Description, Section 13.3: Assessment Methods, Section 13.4: Air, Section 13.5: Terrain and Soils, Section 13.6: Vegetation
# 1  Section 13.1: Introduction, Section 13.2: Project Description, Section 13.3: Assessment Methods, Section 13.4: Air, Section 13.5: Terrain and Soils, Section 13.6: Vegetation
# 2  Section 13.1: Introduction, Section 13.2: Project Description, Section 13.3: Assessment Methods, Section 13.4: Air, Section 13.5: Terrain and Soils, Section 13.6: Vegetation
# 3  Section 13.1: Introduction, Section 13.2: Project Description, Section 13.3: Assessment Methods, Section 13.4: Air, Section 13.5: Terrain and Soils, Section 13.6: Vegetation
# 4  Section 13.1: Introduction, Section 13.2: Project Description, Section 13.3: Assessment Methods, Section 13.4: Air, Section 13.5: Terrain and Soils, Section 13.6: Vegetation
#
#    ESA Section(s) Index       ESA Section(s) Topics CSV Download URL  \
# 0                   1.0  Land, Air, Vegetation, All              NaN
# 1                   1.0  Land, Air, Vegetation, All              NaN
# 2                   1.0  Land, Air, Vegetation, All              NaN
# 3                   1.0  Land, Air, Vegetation, All              NaN
# 4                   1.0  Land, Air, Vegetation, All              NaN
#
#    PDF Page Number  PDF Page Count  PDF Size PDF Outline Download folder name  \
# 0               26           107.0      1.41         Yes                  kwn
# 1               41           107.0      1.41         Yes                  kwn
# 2               44           107.0      1.41         Yes                  kwn
# 3               45           107.0      1.41         Yes                  kwn
# 4               46           107.0      1.41         Yes                  kwn
#
#                         Zipped Project Link
# 0  http://www.cer-rec.gc.ca/esa-ees/kwn.zip
# 1  http://www.cer-rec.gc.ca/esa-ees/kwn.zip
# 2  http://www.cer-rec.gc.ca/esa-ees/kwn.zip
# 3  http://www.cer-rec.gc.ca/esa-ees/kwn.zip
# 4  http://www.cer-rec.gc.ca/esa-ees/kwn.zip

# %%
df_FRA.head()
# Out:
#                                                                                                                                                                  Titre  \
# 0                                                                                                                                  Figure 13.1-1 Pipeline EnCana Ekwan
# 1                                                                                                                             Figure 13.3-1 Cadre de travail de lACEE
# 2                                                            Figure 13.4-1 Normales de température mesurées à laéroport de Fort Nelson pour la période de 1971 à 2000
# 3                      Figure 13.4-2 Pluie mensuelle moyenne et nombre de jours de pluie mesurable observés à laéroport de Fort Nelson pour la période de 1971 à 2000
# 4  Figure 13.4-3 Chute de neige mensuelle moyenne et nombre de jours avec chute de neige mesurable observés à laéroport de Fort Nelson pour la période de 1971 à 2000
#
#   Type de contenu  \
# 0          Figure
# 1          Figure
# 2          Figure
# 3          Figure
# 4          Figure
#
#                                                     Nom de la demande  \
# 0  Demande visant la construction et lexploitation du pipeline Ekwan
# 1  Demande visant la construction et lexploitation du pipeline Ekwan
# 2  Demande visant la construction et lexploitation du pipeline Ekwan
# 3  Demande visant la construction et lexploitation du pipeline Ekwan
# 4  Demande visant la construction et lexploitation du pipeline Ekwan
#
#   Nom abrégé de la demande Dépôt de la demande           Nom de la société  \
# 0                    Ekwan           3/17/2003  EnCana Ekwan Pipeline Inc.
# 1                    Ekwan           3/17/2003  EnCana Ekwan Pipeline Inc.
# 2                    Ekwan           3/17/2003  EnCana Ekwan Pipeline Inc.
# 3                    Ekwan           3/17/2003  EnCana Ekwan Pipeline Inc.
# 4                    Ekwan           3/17/2003  EnCana Ekwan Pipeline Inc.
#
#   Produit de base                             Nom de fichier  \
# 0             Gaz  A0H8C0 - 13.0 EIA - Section 13.1 to 13.6
# 1             Gaz  A0H8C0 - 13.0 EIA - Section 13.1 to 13.6
# 2             Gaz  A0H8C0 - 13.0 EIA - Section 13.1 to 13.6
# 3             Gaz  A0H8C0 - 13.0 EIA - Section 13.1 to 13.6
# 4             Gaz  A0H8C0 - 13.0 EIA - Section 13.1 to 13.6
#
#                                      URL du dossier de lÉES  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/268693
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/268693
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/268693
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/268693
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/268693
#
#   Numéro de document  Identificateur de données  \
# 0             A0H8C0                     268706
# 1             A0H8C0                     268706
# 2             A0H8C0                     268706
# 3             A0H8C0                     268706
# 4             A0H8C0                     268706
#
#                                  URL de téléchargement PDF  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/268706
# 1  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/268706
# 2  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/268706
# 3  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/268706
# 4  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/268706
#
#   Type de demande (Loi sur lOffice national de lénergie)  \
# 0              Projets de grande envergure (plus de 40 km)
# 1              Projets de grande envergure (plus de 40 km)
# 2              Projets de grande envergure (plus de 40 km)
# 3              Projets de grande envergure (plus de 40 km)
# 4              Projets de grande envergure (plus de 40 km)
#
#          Emplacement du pipeline Ordonnance daudience  \
# 0  Alberta, Colombie britannique             GH-1-2003
# 1  Alberta, Colombie britannique             GH-1-2003
# 2  Alberta, Colombie britannique             GH-1-2003
# 3  Alberta, Colombie britannique             GH-1-2003
# 4  Alberta, Colombie britannique             GH-1-2003
#
#                     Nom du consultant État d'avancement  \
# 0  AXYS Environmental Consulting Ltd.   En exploitation
# 1  AXYS Environmental Consulting Ltd.   En exploitation
# 2  AXYS Environmental Consulting Ltd.   En exploitation
# 3  AXYS Environmental Consulting Ltd.   En exploitation
# 4  AXYS Environmental Consulting Ltd.   En exploitation
#
#   Instruments réglementaires  \
# 0                     GC-108
# 1                     GC-108
# 2                     GC-108
# 3                     GC-108
# 4                     GC-108
#
#                                      URL de la demande  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/268876
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/268876
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/268876
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/268876
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/268876
#
#                                                      URL de la décision  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/293763
# 1  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/293763
# 2  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/293763
# 3  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/293763
# 4  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/293763
#
#                                                                                                                                                                         Sections de lEES  \
# 0  Section 13.1 : Introduction, Section 13.2 : Description du projet, Section 13.3 : Méthodes d'évaluation, Section 13.4 : Air, Section 13.5 : Terrain et sols, Section 13.6 : Végétation
# 1  Section 13.1 : Introduction, Section 13.2 : Description du projet, Section 13.3 : Méthodes d'évaluation, Section 13.4 : Air, Section 13.5 : Terrain et sols, Section 13.6 : Végétation
# 2  Section 13.1 : Introduction, Section 13.2 : Description du projet, Section 13.3 : Méthodes d'évaluation, Section 13.4 : Air, Section 13.5 : Terrain et sols, Section 13.6 : Végétation
# 3  Section 13.1 : Introduction, Section 13.2 : Description du projet, Section 13.3 : Méthodes d'évaluation, Section 13.4 : Air, Section 13.5 : Terrain et sols, Section 13.6 : Végétation
# 4  Section 13.1 : Introduction, Section 13.2 : Description du projet, Section 13.3 : Méthodes d'évaluation, Section 13.4 : Air, Section 13.5 : Terrain et sols, Section 13.6 : Végétation
#
#    Index des sections de lÉES Sujets des sections de lÉES  \
# 0                          1.0      Terres, Air, Végétation
# 1                          1.0      Terres, Air, Végétation
# 2                          1.0      Terres, Air, Végétation
# 3                          1.0      Terres, Air, Végétation
# 4                          1.0      Terres, Air, Végétation
#
#   URL de téléchargement CSV  Numéro de page PDF  Nombre de pages PDF  \
# 0                       NaN                  26                107.0
# 1                       NaN                  41                107.0
# 2                       NaN                  44                107.0
# 3                       NaN                  45                107.0
# 4                       NaN                  46                107.0
#
#    Taille PDF Aperçu PDF Télécharger le nom du dossier  \
# 0        1.41        Oui                           kwn
# 1        1.41        Oui                           kwn
# 2        1.41        Oui                           kwn
# 3        1.41        Oui                           kwn
# 4        1.41        Oui                           kwn
#
#               Lien vers le projet compressé
# 0  http://www.cer-rec.gc.ca/esa-ees/kwn.zip
# 1  http://www.cer-rec.gc.ca/esa-ees/kwn.zip
# 2  http://www.cer-rec.gc.ca/esa-ees/kwn.zip
# 3  http://www.cer-rec.gc.ca/esa-ees/kwn.zip
# 4  http://www.cer-rec.gc.ca/esa-ees/kwn.zip

# %%
# Remove all rows for figures so that we are only moving tables
df = df[df['Content Type'] == 'Table']
df_FRA = df_FRA[df_FRA['Type de contenu'] == 'Tableau']

# %%
df_bad_DataIDs = pd.read_csv("H:/esa-intermediate-code/data_id_to_be_excluded.csv")

# %%
df['bad_csv'] = df['Data ID'].isin(list(df_bad_DataIDs.values))
df_FRA['mauvais_csv'] = df_FRA['Identificateur de données'].isin(list(df_bad_DataIDs.values))

# %%
df.head()
# Out:
#                                                                                                  Title  \
# 9134   TABLE 3 SUMMARY OF AQUATICS FIELD WORK AND ABORIGINAL FIELD STUDY PARTICIPATION FOR THE PROJECT
# 9135  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 9136  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 9137  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 9138  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
#
#      Content Type                       Application Name  \
# 9134        Table  Application for North Montney Project
# 9135        Table  Application for North Montney Project
# 9136        Table  Application for North Montney Project
# 9137        Table  Application for North Montney Project
# 9138        Table  Application for North Montney Project
#
#      Application Short Name Application Filing Date  \
# 9134          North Montney               11/8/2013
# 9135          North Montney               11/8/2013
# 9136          North Montney               11/8/2013
# 9137          North Montney               11/8/2013
# 9138          North Montney               11/8/2013
#
#                     Company Name Commodity  \
# 9134  NOVA Gas Transmission Ltd.       Gas
# 9135  NOVA Gas Transmission Ltd.       Gas
# 9136  NOVA Gas Transmission Ltd.       Gas
# 9137  NOVA Gas Transmission Ltd.       Gas
# 9138  NOVA Gas Transmission Ltd.       Gas
#
#                                    File Name  \
# 9134  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 9135  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 9136  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 9137  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 9138  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
#
#                                                   ESA Folder URL  \
# 9134  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 9135  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 9136  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 9137  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 9138  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
#
#      Document Number  Data ID  \
# 9134          A3Q6H2  1059614
# 9135          A3Q6H2  1059614
# 9136          A3Q6H2  1059614
# 9137          A3Q6H2  1059614
# 9138          A3Q6H2  1059614
#
#                                               PDF Download URL  \
# 9134  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 9135  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 9136  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 9137  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 9138  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
#
#        Application Type (NEB Act)      Pipeline Location Hearing order  \
# 9134  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
# 9135  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
# 9136  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
# 9137  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
# 9138  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
#
#                                               Consultant Name Pipeline Status  \
# 9134  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 9135  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 9136  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 9137  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 9138  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
#
#      Regulatory Instrument(s)  \
# 9134                   GC-125
# 9135                   GC-125
# 9136                   GC-125
# 9137                   GC-125
# 9138                   GC-125
#
#                                            Application URL  \
# 9134  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 9135  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 9136  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 9137  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 9138  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
#
#                                               Decision URL  \
# 9134  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 9135  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 9136  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 9137  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 9138  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
#
#                                 ESA Section(s)  ESA Section(s) Index  \
# 9134  Appendix G: TERA Aquatics Summary Report                  15.0
# 9135  Appendix G: TERA Aquatics Summary Report                  15.0
# 9136  Appendix G: TERA Aquatics Summary Report                  15.0
# 9137  Appendix G: TERA Aquatics Summary Report                  15.0
# 9138  Appendix G: TERA Aquatics Summary Report                  15.0
#
#      ESA Section(s) Topics  \
# 9134            Water, All
# 9135            Water, All
# 9136            Water, All
# 9137            Water, All
# 9138            Water, All
#
#                                                 CSV Download URL  \
# 9134  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_14_1.csv
# 9135  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_17_1.csv
# 9136  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_18_1.csv
# 9137  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_19_1.csv
# 9138  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_20_1.csv
#
#       PDF Page Number  PDF Page Count  PDF Size PDF Outline  \
# 9134               14            48.0      5.87          No
# 9135               17            48.0      5.87          No
# 9136               18            48.0      5.87          No
# 9137               19            48.0      5.87          No
# 9138               20            48.0      5.87          No
#
#      Download folder name                            Zipped Project Link  \
# 9134             nrthmntn  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
# 9135             nrthmntn  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
# 9136             nrthmntn  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
# 9137             nrthmntn  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
# 9138             nrthmntn  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip
#
#       bad_csv
# 9134    False
# 9135    False
# 9136    False
# 9137    False
# 9138    False

# %%
# Dropping old index column to create new one
# df.drop(columns=['Unnamed: 0'], inplace=True)
df = df.reset_index()
df.rename(columns = {"index": "Index"}, inplace = True) 

# df_FRA.drop(columns=['Unnamed: 0'], inplace=True)
df_FRA = df_FRA.reset_index()
df_FRA.rename(columns = {"index": "Indice"}, inplace = True)

# %%
df_FRA.head()
# Out:
#    Indice  \
# 0    9134
# 1    9135
# 2    9136
# 3    9137
# 4    9138
#
#                                                                                                                                  Titre  \
# 0  TABLEAU 3 RÉSUMÉ DU TRAVAIL SUR LE TERRAIN AQUATIQUE ET DE LA PARTICIPATION DES AUTOCHTONES À LÉTUDE SUR LE TERRAIN POUR LE PROJET
# 1              TABLEAU 4 RÉSUMÉ DES FRANCHISSEMENTS DE COURS DEAU DE LA CANALISATION PRINCIPALE NORTH MONTNEY (TRONÇON AITKEN CREEK)
# 2              TABLEAU 4 RÉSUMÉ DES FRANCHISSEMENTS DE COURS DEAU DE LA CANALISATION PRINCIPALE NORTH MONTNEY (TRONÇON AITKEN CREEK)
# 3              TABLEAU 4 RÉSUMÉ DES FRANCHISSEMENTS DE COURS DEAU DE LA CANALISATION PRINCIPALE NORTH MONTNEY (TRONÇON AITKEN CREEK)
# 4              TABLEAU 4 RÉSUMÉ DES FRANCHISSEMENTS DE COURS DEAU DE LA CANALISATION PRINCIPALE NORTH MONTNEY (TRONÇON AITKEN CREEK)
#
#   Type de contenu                       Nom de la demande  \
# 0         Tableau  Demande visant le projet North Montney
# 1         Tableau  Demande visant le projet North Montney
# 2         Tableau  Demande visant le projet North Montney
# 3         Tableau  Demande visant le projet North Montney
# 4         Tableau  Demande visant le projet North Montney
#
#   Nom abrégé de la demande Dépôt de la demande           Nom de la société  \
# 0            North Montney           11/8/2013  NOVA Gas Transmission Ltd.
# 1            North Montney           11/8/2013  NOVA Gas Transmission Ltd.
# 2            North Montney           11/8/2013  NOVA Gas Transmission Ltd.
# 3            North Montney           11/8/2013  NOVA Gas Transmission Ltd.
# 4            North Montney           11/8/2013  NOVA Gas Transmission Ltd.
#
#   Produit de base                          Nom de fichier  \
# 0             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 1             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 2             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 3             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 4             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
#
#                                       URL du dossier de lÉES  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
#
#   Numéro de document  Identificateur de données  \
# 0             A3Q6H2                    1059614
# 1             A3Q6H2                    1059614
# 2             A3Q6H2                    1059614
# 3             A3Q6H2                    1059614
# 4             A3Q6H2                    1059614
#
#                                   URL de téléchargement PDF  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 1  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 2  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 3  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 4  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
#
#   Type de demande (Loi sur lOffice national de lénergie)  \
# 0              Projets de grande envergure (plus de 40 km)
# 1              Projets de grande envergure (plus de 40 km)
# 2              Projets de grande envergure (plus de 40 km)
# 3              Projets de grande envergure (plus de 40 km)
# 4              Projets de grande envergure (plus de 40 km)
#
#   Emplacement du pipeline Ordonnance daudience  \
# 0    Colombie britannique           GH-001-2014
# 1    Colombie britannique           GH-001-2014
# 2    Colombie britannique           GH-001-2014
# 3    Colombie britannique           GH-001-2014
# 4    Colombie britannique           GH-001-2014
#
#                                          Nom du consultant État d'avancement  \
# 0  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
# 1  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
# 2  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
# 3  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
# 4  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
#
#   Instruments réglementaires  \
# 0                     GC-125
# 1                     GC-125
# 2                     GC-125
# 3                     GC-125
# 4                     GC-125
#
#                                       URL de la demande  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
#
#                                                       URL de la décision  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
# 1  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
# 2  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
# 3  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
# 4  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
#
#                                              Sections de lEES  \
# 0  Annexe G : Rapport sommaire de TERA sur le milieu aquatique
# 1  Annexe G : Rapport sommaire de TERA sur le milieu aquatique
# 2  Annexe G : Rapport sommaire de TERA sur le milieu aquatique
# 3  Annexe G : Rapport sommaire de TERA sur le milieu aquatique
# 4  Annexe G : Rapport sommaire de TERA sur le milieu aquatique
#
#    Index des sections de lÉES Sujets des sections de lÉES  \
# 0                         15.0                          Eau
# 1                         15.0                          Eau
# 2                         15.0                          Eau
# 3                         15.0                          Eau
# 4                         15.0                          Eau
#
#                                     URL de téléchargement CSV  \
# 0  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_14_1.csv
# 1  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_17_1.csv
# 2  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_18_1.csv
# 3  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_19_1.csv
# 4  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_20_1.csv
#
#    Numéro de page PDF  Nombre de pages PDF  Taille PDF Aperçu PDF  \
# 0                  14                 48.0        5.87        Non
# 1                  17                 48.0        5.87        Non
# 2                  18                 48.0        5.87        Non
# 3                  19                 48.0        5.87        Non
# 4                  20                 48.0        5.87        Non
#
#   Télécharger le nom du dossier  \
# 0                      nrthmntn
# 1                      nrthmntn
# 2                      nrthmntn
# 3                      nrthmntn
# 4                      nrthmntn
#
#                    Lien vers le projet compressé  mauvais_csv
# 0  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip        False
# 1  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip        False
# 2  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip        False
# 3  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip        False
# 4  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip        False

# %%
# Creating the names of each csv file
df['filename'] = df['Download folder name'] + '_' + df['Title'].str.lower().str.replace('(', '').str.replace(')', '').str.replace(' ', '-').str.replace('.', '-').str.replace('[^\w+-]', '').str.slice(0,50)

df_FRA['nom_du_fichier'] = df_FRA['Télécharger le nom du dossier'] + '_' + df_FRA['Titre'].str.lower().str.replace('(', '').str.replace(')', '').str.replace(' ', '-').str.replace('.', '-').str.replace('[^\w+-]', '').str.slice(0,50)

# %%
df.head()
# Out:
#    Index  \
# 0   9134
# 1   9135
# 2   9136
# 3   9137
# 4   9138
#
#                                                                                               Title  \
# 0   TABLE 3 SUMMARY OF AQUATICS FIELD WORK AND ABORIGINAL FIELD STUDY PARTICIPATION FOR THE PROJECT
# 1  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 2  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 3  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 4  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
#
#   Content Type                       Application Name Application Short Name  \
# 0        Table  Application for North Montney Project          North Montney
# 1        Table  Application for North Montney Project          North Montney
# 2        Table  Application for North Montney Project          North Montney
# 3        Table  Application for North Montney Project          North Montney
# 4        Table  Application for North Montney Project          North Montney
#
#   Application Filing Date                Company Name Commodity  \
# 0               11/8/2013  NOVA Gas Transmission Ltd.       Gas
# 1               11/8/2013  NOVA Gas Transmission Ltd.       Gas
# 2               11/8/2013  NOVA Gas Transmission Ltd.       Gas
# 3               11/8/2013  NOVA Gas Transmission Ltd.       Gas
# 4               11/8/2013  NOVA Gas Transmission Ltd.       Gas
#
#                                 File Name  \
# 0  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 1  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 2  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 3  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 4  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
#
#                                                ESA Folder URL Document Number  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
#
#    Data ID                                          PDF Download URL  \
# 0  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 1  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 2  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 3  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 4  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
#
#     Application Type (NEB Act)      Pipeline Location Hearing order  \
# 0  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
# 1  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
# 2  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
# 3  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
# 4  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
#
#                                            Consultant Name Pipeline Status  \
# 0  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 1  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 2  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 3  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 4  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
#
#   Regulatory Instrument(s)  \
# 0                   GC-125
# 1                   GC-125
# 2                   GC-125
# 3                   GC-125
# 4                   GC-125
#
#                                         Application URL  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
#
#                                            Decision URL  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
#
#                              ESA Section(s)  ESA Section(s) Index  \
# 0  Appendix G: TERA Aquatics Summary Report                  15.0
# 1  Appendix G: TERA Aquatics Summary Report                  15.0
# 2  Appendix G: TERA Aquatics Summary Report                  15.0
# 3  Appendix G: TERA Aquatics Summary Report                  15.0
# 4  Appendix G: TERA Aquatics Summary Report                  15.0
#
#   ESA Section(s) Topics  \
# 0            Water, All
# 1            Water, All
# 2            Water, All
# 3            Water, All
# 4            Water, All
#
#                                              CSV Download URL  \
# 0  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_14_1.csv
# 1  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_17_1.csv
# 2  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_18_1.csv
# 3  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_19_1.csv
# 4  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/1059614_20_1.csv
#
#    PDF Page Number  PDF Page Count  PDF Size PDF Outline Download folder name  \
# 0               14            48.0      5.87          No             nrthmntn
# 1               17            48.0      5.87          No             nrthmntn
# 2               18            48.0      5.87          No             nrthmntn
# 3               19            48.0      5.87          No             nrthmntn
# 4               20            48.0      5.87          No             nrthmntn
#
#                              Zipped Project Link  bad_csv  \
# 0  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip    False
# 1  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip    False
# 2  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip    False
# 3  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip    False
# 4  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip    False
#
#                                                       filename
# 0  nrthmntn_table-3-summary-of-aquatics-field-work-and-aborigi
# 1  nrthmntn_table-4-summary-of-watercourse-crossings-along-the
# 2  nrthmntn_table-4-summary-of-watercourse-crossings-along-the
# 3  nrthmntn_table-4-summary-of-watercourse-crossings-along-the
# 4  nrthmntn_table-4-summary-of-watercourse-crossings-along-the

# %%
# Creating a column with the old filename so that we can rename the files
old_filename_df = df['CSV Download URL'].str.split('/').str[-1].str.split('_')
df['old_filename'] = old_filename_df.str[0] + '_' + old_filename_df.str[1] + '_lattice-v_' + old_filename_df.str[2]

vieux_nom_du_fichier_df = df_FRA['URL de téléchargement CSV'].str.split('/').str[-1].str.split('_')
df_FRA['vieux_nom_de_fichier'] = vieux_nom_du_fichier_df.str[0] + '_' + vieux_nom_du_fichier_df.str[1] + '_lattice-v_' + vieux_nom_du_fichier_df.str[2]

# %%
df['old_filename']
# Out:
# 0        1059614_14_lattice-v_1.csv
# 1        1059614_17_lattice-v_1.csv
# 2        1059614_18_lattice-v_1.csv
# 3        1059614_19_lattice-v_1.csv
# 4        1059614_20_lattice-v_1.csv
#                     ...
# 28886     895339_10_lattice-v_1.csv
# 28887     895339_12_lattice-v_1.csv
# 28888     895339_13_lattice-v_1.csv
# 28889     895339_14_lattice-v_1.csv
# 28890     895339_23_lattice-v_1.csv
# Name: old_filename, Length: 28891, dtype: object

# %%
# %%time
# We add a counter for all CSVs connected to the same table
# For the English index file
prev_title = ''
for index, row in df.iterrows():
    current_title = row['filename']
    if current_title == prev_title:
        i += 1
        current_title = current_title + '_pt-' + str(i) + '_pg-' + str(row['PDF Page Number']) + '_doc-num-' + str(row['Document Number']) + '.csv'
    else:
        i = 1
        current_title = current_title + '_pt-' + str(i) + '_pg-' + str(row['PDF Page Number']) + '_doc-num-' + str(row['Document Number']) + '.csv'
    
    df.loc[index, 'filename'] = current_title
    df.loc[index, 'CSV Download URL'] = os.path.join('http://www.cer-rec.gc.ca/esa-ees/', row['Download folder name'] + '/' + current_title)
    prev_title = row['filename']
# Out:
# Wall time: 1min 34s

# %%
df.head(5)
# Out:
#    Index  \
# 0   9134
# 1   9135
# 2   9136
# 3   9137
# 4   9138
#
#                                                                                               Title  \
# 0   TABLE 3 SUMMARY OF AQUATICS FIELD WORK AND ABORIGINAL FIELD STUDY PARTICIPATION FOR THE PROJECT
# 1  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 2  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 3  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
# 4  TABLE 4 SUMMARY OF WATERCOURSE CROSSINGS ALONG THE NORTH MONTNEY MAINLINE (AITKEN CREEK SECTION)
#
#   Content Type                       Application Name Application Short Name  \
# 0        Table  Application for North Montney Project          North Montney
# 1        Table  Application for North Montney Project          North Montney
# 2        Table  Application for North Montney Project          North Montney
# 3        Table  Application for North Montney Project          North Montney
# 4        Table  Application for North Montney Project          North Montney
#
#   Application Filing Date                Company Name Commodity  \
# 0               11/8/2013  NOVA Gas Transmission Ltd.       Gas
# 1               11/8/2013  NOVA Gas Transmission Ltd.       Gas
# 2               11/8/2013  NOVA Gas Transmission Ltd.       Gas
# 3               11/8/2013  NOVA Gas Transmission Ltd.       Gas
# 4               11/8/2013  NOVA Gas Transmission Ltd.       Gas
#
#                                 File Name  \
# 0  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 1  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 2  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 3  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 4  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
#
#                                                ESA Folder URL Document Number  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040          A3Q6H2
#
#    Data ID                                          PDF Download URL  \
# 0  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 1  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 2  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 3  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 4  1059614  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
#
#     Application Type (NEB Act)      Pipeline Location Hearing order  \
# 0  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
# 1  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
# 2  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
# 3  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
# 4  Large Projects (over 40 km)  British Columbia, All   GH-001-2014
#
#                                            Consultant Name Pipeline Status  \
# 0  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 1  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 2  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 3  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
# 4  Stantec Consulting Ltd., TERA Environmental Consultants       Operating
#
#   Regulatory Instrument(s)  \
# 0                   GC-125
# 1                   GC-125
# 2                   GC-125
# 3                   GC-125
# 4                   GC-125
#
#                                         Application URL  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
#
#                                            Decision URL  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/3890551
#
#                              ESA Section(s)  ESA Section(s) Index  \
# 0  Appendix G: TERA Aquatics Summary Report                  15.0
# 1  Appendix G: TERA Aquatics Summary Report                  15.0
# 2  Appendix G: TERA Aquatics Summary Report                  15.0
# 3  Appendix G: TERA Aquatics Summary Report                  15.0
# 4  Appendix G: TERA Aquatics Summary Report                  15.0
#
#   ESA Section(s) Topics  \
# 0            Water, All
# 1            Water, All
# 2            Water, All
# 3            Water, All
# 4            Water, All
#
#                                                                                                                       CSV Download URL  \
# 0  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn_table-3-summary-of-aquatics-field-work-and-aborigi_pt-1_pg-14_doc-num-A3Q6H2.csv
# 1  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn_table-4-summary-of-watercourse-crossings-along-the_pt-1_pg-17_doc-num-A3Q6H2.csv
# 2  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn_table-4-summary-of-watercourse-crossings-along-the_pt-2_pg-18_doc-num-A3Q6H2.csv
# 3  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn_table-4-summary-of-watercourse-crossings-along-the_pt-3_pg-19_doc-num-A3Q6H2.csv
# 4  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn_table-4-summary-of-watercourse-crossings-along-the_pt-4_pg-20_doc-num-A3Q6H2.csv
#
#    PDF Page Number  PDF Page Count  PDF Size PDF Outline Download folder name  \
# 0               14            48.0      5.87          No             nrthmntn
# 1               17            48.0      5.87          No             nrthmntn
# 2               18            48.0      5.87          No             nrthmntn
# 3               19            48.0      5.87          No             nrthmntn
# 4               20            48.0      5.87          No             nrthmntn
#
#                              Zipped Project Link  bad_csv  \
# 0  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip    False
# 1  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip    False
# 2  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip    False
# 3  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip    False
# 4  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip    False
#
#                                                                                     filename  \
# 0  nrthmntn_table-3-summary-of-aquatics-field-work-and-aborigi_pt-1_pg-14_doc-num-A3Q6H2.csv
# 1  nrthmntn_table-4-summary-of-watercourse-crossings-along-the_pt-1_pg-17_doc-num-A3Q6H2.csv
# 2  nrthmntn_table-4-summary-of-watercourse-crossings-along-the_pt-2_pg-18_doc-num-A3Q6H2.csv
# 3  nrthmntn_table-4-summary-of-watercourse-crossings-along-the_pt-3_pg-19_doc-num-A3Q6H2.csv
# 4  nrthmntn_table-4-summary-of-watercourse-crossings-along-the_pt-4_pg-20_doc-num-A3Q6H2.csv
#
#                  old_filename
# 0  1059614_14_lattice-v_1.csv
# 1  1059614_17_lattice-v_1.csv
# 2  1059614_18_lattice-v_1.csv
# 3  1059614_19_lattice-v_1.csv
# 4  1059614_20_lattice-v_1.csv

# %%
# %%time
# For French index file
prev_title = ''
for index, row in df_FRA.iterrows():
    current_title = row['nom_du_fichier']
    if current_title == prev_title:
        i += 1
        current_title = current_title + '_pt-' + str(i) + '_pg-' + str(row['Numéro de page PDF']) + '_num-du-doc-' + str(row['Numéro de document']) + '.csv'
    else:
        i = 1
        current_title = current_title + '_pt-' + str(i) + '_pg-' + str(row['Numéro de page PDF']) + '_num-du-doc-' + str(row['Numéro de document']) + '.csv'
    
    df_FRA.loc[index, 'nom_du_fichier'] = current_title
    df_FRA.loc[index, 'URL de téléchargement CSV'] = os.path.join('http://www.cer-rec.gc.ca/esa-ees/', row['Télécharger le nom du dossier'] + '/' + current_title)
    prev_title = row['nom_du_fichier']
# Out:
# Wall time: 1min 34s

# %%
df_FRA.head(5)
# Out:
#    Indice  \
# 0    9134
# 1    9135
# 2    9136
# 3    9137
# 4    9138
#
#                                                                                                                                  Titre  \
# 0  TABLEAU 3 RÉSUMÉ DU TRAVAIL SUR LE TERRAIN AQUATIQUE ET DE LA PARTICIPATION DES AUTOCHTONES À LÉTUDE SUR LE TERRAIN POUR LE PROJET
# 1              TABLEAU 4 RÉSUMÉ DES FRANCHISSEMENTS DE COURS DEAU DE LA CANALISATION PRINCIPALE NORTH MONTNEY (TRONÇON AITKEN CREEK)
# 2              TABLEAU 4 RÉSUMÉ DES FRANCHISSEMENTS DE COURS DEAU DE LA CANALISATION PRINCIPALE NORTH MONTNEY (TRONÇON AITKEN CREEK)
# 3              TABLEAU 4 RÉSUMÉ DES FRANCHISSEMENTS DE COURS DEAU DE LA CANALISATION PRINCIPALE NORTH MONTNEY (TRONÇON AITKEN CREEK)
# 4              TABLEAU 4 RÉSUMÉ DES FRANCHISSEMENTS DE COURS DEAU DE LA CANALISATION PRINCIPALE NORTH MONTNEY (TRONÇON AITKEN CREEK)
#
#   Type de contenu                       Nom de la demande  \
# 0         Tableau  Demande visant le projet North Montney
# 1         Tableau  Demande visant le projet North Montney
# 2         Tableau  Demande visant le projet North Montney
# 3         Tableau  Demande visant le projet North Montney
# 4         Tableau  Demande visant le projet North Montney
#
#   Nom abrégé de la demande Dépôt de la demande           Nom de la société  \
# 0            North Montney           11/8/2013  NOVA Gas Transmission Ltd.
# 1            North Montney           11/8/2013  NOVA Gas Transmission Ltd.
# 2            North Montney           11/8/2013  NOVA Gas Transmission Ltd.
# 3            North Montney           11/8/2013  NOVA Gas Transmission Ltd.
# 4            North Montney           11/8/2013  NOVA Gas Transmission Ltd.
#
#   Produit de base                          Nom de fichier  \
# 0             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 1             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 2             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 3             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
# 4             Gaz  B2-16 ESA_Appendix_G_Part1of4 (A3Q6H2)
#
#                                       URL du dossier de lÉES  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/LoadResult/1060040
#
#   Numéro de document  Identificateur de données  \
# 0             A3Q6H2                    1059614
# 1             A3Q6H2                    1059614
# 2             A3Q6H2                    1059614
# 3             A3Q6H2                    1059614
# 4             A3Q6H2                    1059614
#
#                                   URL de téléchargement PDF  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 1  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 2  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 3  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
# 4  https://apps.cer-rec.gc.ca/REGDOCS/File/Download/1059614
#
#   Type de demande (Loi sur lOffice national de lénergie)  \
# 0              Projets de grande envergure (plus de 40 km)
# 1              Projets de grande envergure (plus de 40 km)
# 2              Projets de grande envergure (plus de 40 km)
# 3              Projets de grande envergure (plus de 40 km)
# 4              Projets de grande envergure (plus de 40 km)
#
#   Emplacement du pipeline Ordonnance daudience  \
# 0    Colombie britannique           GH-001-2014
# 1    Colombie britannique           GH-001-2014
# 2    Colombie britannique           GH-001-2014
# 3    Colombie britannique           GH-001-2014
# 4    Colombie britannique           GH-001-2014
#
#                                          Nom du consultant État d'avancement  \
# 0  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
# 1  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
# 2  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
# 3  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
# 4  Stantec Consulting Ltd., TERA Environmental Consultants   En exploitation
#
#   Instruments réglementaires  \
# 0                     GC-125
# 1                     GC-125
# 2                     GC-125
# 3                     GC-125
# 4                     GC-125
#
#                                       URL de la demande  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 1  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 2  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 3  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
# 4  https://apps.cer-rec.gc.ca/REGDOCS/Item/View/1060220
#
#                                                       URL de la décision  \
# 0  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
# 1  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
# 2  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
# 3  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
# 4  https://apps.cer-rec.gc.ca/REGDOCS/%C3%89l%C3%A9ment/Afficher/3890551
#
#                                              Sections de lEES  \
# 0  Annexe G : Rapport sommaire de TERA sur le milieu aquatique
# 1  Annexe G : Rapport sommaire de TERA sur le milieu aquatique
# 2  Annexe G : Rapport sommaire de TERA sur le milieu aquatique
# 3  Annexe G : Rapport sommaire de TERA sur le milieu aquatique
# 4  Annexe G : Rapport sommaire de TERA sur le milieu aquatique
#
#    Index des sections de lÉES Sujets des sections de lÉES  \
# 0                         15.0                          Eau
# 1                         15.0                          Eau
# 2                         15.0                          Eau
# 3                         15.0                          Eau
# 4                         15.0                          Eau
#
#                                                                                                                 URL de téléchargement CSV  \
# 0  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn_tableau-3-résumé-du-travail-sur-le-terrain-aquatiq_pt-1_pg-14_num-du-doc-A3Q6H2.csv
# 1  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn_tableau-4-résumé-des-franchissements-de-cours-deau_pt-1_pg-17_num-du-doc-A3Q6H2.csv
# 2  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn_tableau-4-résumé-des-franchissements-de-cours-deau_pt-2_pg-18_num-du-doc-A3Q6H2.csv
# 3  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn_tableau-4-résumé-des-franchissements-de-cours-deau_pt-3_pg-19_num-du-doc-A3Q6H2.csv
# 4  http://www.cer-rec.gc.ca/esa-ees/nrthmntn/nrthmntn_tableau-4-résumé-des-franchissements-de-cours-deau_pt-4_pg-20_num-du-doc-A3Q6H2.csv
#
#    Numéro de page PDF  Nombre de pages PDF  Taille PDF Aperçu PDF  \
# 0                  14                 48.0        5.87        Non
# 1                  17                 48.0        5.87        Non
# 2                  18                 48.0        5.87        Non
# 3                  19                 48.0        5.87        Non
# 4                  20                 48.0        5.87        Non
#
#   Télécharger le nom du dossier  \
# 0                      nrthmntn
# 1                      nrthmntn
# 2                      nrthmntn
# 3                      nrthmntn
# 4                      nrthmntn
#
#                    Lien vers le projet compressé  mauvais_csv  \
# 0  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip        False
# 1  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip        False
# 2  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip        False
# 3  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip        False
# 4  http://www.cer-rec.gc.ca/esa-ees/nrthmntn.zip        False
#
#                                                                                  nom_du_fichier  \
# 0  nrthmntn_tableau-3-résumé-du-travail-sur-le-terrain-aquatiq_pt-1_pg-14_num-du-doc-A3Q6H2.csv
# 1  nrthmntn_tableau-4-résumé-des-franchissements-de-cours-deau_pt-1_pg-17_num-du-doc-A3Q6H2.csv
# 2  nrthmntn_tableau-4-résumé-des-franchissements-de-cours-deau_pt-2_pg-18_num-du-doc-A3Q6H2.csv
# 3  nrthmntn_tableau-4-résumé-des-franchissements-de-cours-deau_pt-3_pg-19_num-du-doc-A3Q6H2.csv
# 4  nrthmntn_tableau-4-résumé-des-franchissements-de-cours-deau_pt-4_pg-20_num-du-doc-A3Q6H2.csv
#
#          vieux_nom_de_fichier
# 0  1059614_14_lattice-v_1.csv
# 1  1059614_17_lattice-v_1.csv
# 2  1059614_18_lattice-v_1.csv
# 3  1059614_19_lattice-v_1.csv
# 4  1059614_20_lattice-v_1.csv

# %%
# Adding an index ID to each file to avoid duplicates
# Add only if there are duplicates
# df['filename'] = df['filename'] + '-' + 'no' + df['Index'].astype(str) + '.csv'
# df_FRA['nom_du_fichier'] = df_FRA['nom_du_fichier'] + '-' + 'no' + df_FRA['Indice'].astype(str) + '.csv'

# %%
# Making sure there are no duplicates in English filenames
assert len(df) - len(df['filename'].unique()) == 0, "Should be 0. Instead, it is " + str(len(df) - len(df['filename'].unique())) + '.'

# %%
# Making sure there are no duplicates in French filenames
assert len(df_FRA) - len(df_FRA['nom_du_fichier'].unique()) == 0, "Should be 0. Instead, it is " + str(len(df_FRA) - len(df_FRA['nom_du_fichier'].unique())) + '.'

# %%
df['bad_csv'].value_counts()
# Out:
# False    26665
# True      2226
# Name: bad_csv, dtype: int64

# %%
# Where the CSVs are located
csv_folder_path_ENG = 'F:/Environmental Baseline Data/Version 4 - Final/all_csvs_cleaned_latest_ENG/'
csv_folder_path_FRA = 'F:/Environmental Baseline Data/Version 4 - Final/all_csvs_cleaned_latest_FRA/'

# %%
# %%time
# English CSVs
# If the final file has been renamed, it will skip the renaming loop
os.chdir(csv_folder_path_ENG)
if os.path.isfile(df['old_filename'].iloc[-1]):
  #loop through the name and rename
    for index, row in df.iterrows():
        if os.path.isfile(row['old_filename']):
            if row['bad_csv'] == False:
                shutil.move(row['old_filename'], row['filename'])
            else:
                os.remove(row['old_filename'])
# Out:
# Wall time: 5min 48s

# %%
# %%time
# French CSVs
# If the final file has been renamed, it will skip the renaming loop
os.chdir(csv_folder_path_FRA)
if os.path.isfile(df_FRA['vieux_nom_de_fichier'].iloc[-1]):
  #loop through the name and rename
    for index, row in df_FRA.iterrows():
        if os.path.isfile(row['vieux_nom_de_fichier']):
            if row['mauvais_csv'] == False:
                shutil.move(row['vieux_nom_de_fichier'], row['nom_du_fichier'])
            else:
                os.remove(row['vieux_nom_de_fichier'])
# Out:
# Wall time: 5min 47s

# %%
# Updating base path to Indices folder to save index files
os.chdir('F:/Environmental Baseline Data/Version 4 - Final/Indices/')

# %%
# Saving index files
df.to_csv('ESA_website_ENG_' + strftime("%Y_%m_%d", localtime()) + '_final' + '.csv', encoding='ISO-8859-1', index=False)
df_FRA.to_csv('ESA_website_FRA_' + strftime("%Y_%m_%d", localtime()) + '_final' + '.csv', encoding='ISO-8859-1', index=False)
